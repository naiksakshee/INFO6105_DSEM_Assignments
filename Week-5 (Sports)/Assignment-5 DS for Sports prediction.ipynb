# %%
class ProbDist(dict):
    """A Probability Distribution; an {outcome: probability} mapping."""
    def __init__(self, mapping=(), **kwargs):
        self.update(mapping, **kwargs)
        # Make probabilities sum to 1.0; assert no negative probabilities
        total = sum(self.values())
        for outcome in self:
            self[outcome] = self[outcome] / total
            assert self[outcome] >= 0

# %%
def p(event , space): 
    """The probability of an event, given a sample space of equiprobable outcomes. 
    event: a collection of outcomes, or a predicate that is true of outcomes in the event. 
    space: a set of outcomes or a probability distribution of {outcome: frequency} pairs."""
    if is_predicate(event):
        event = such_that(event, space)
    if isinstance(space, ProbDist):
        return sum(space[o] for o in space if o in event)
    else:
        return Fraction(len(event & space), len(space))

is_predicate = callable

def such_that(predicate, space): 
    """The outcomes in the sample pace for which the predicate is true.
    If space is a set, return a subset {outcome,...} with outcomes where predicate(element) is true;
    if space is a ProbDist, return a ProbDist {outcome: frequency,...} with outcomes where predicate(element) is true."""
    if isinstance(space, ProbDist):
        return ProbDist({o:space[o] for o in space if predicate(o)})
    else:
        return {o for o in space if predicate(o)}

# %% [markdown]
# ### Probability Distribution for Germany Grand Prix

# %%
GGP = ProbDist(
    LH = 347,
    VB = 223,
    MV = 214,
    SP = 125,
    DR = 119,
    CS = 105,
    AA = 105,
    CL = 98,
    LN = 97,
    PG = 75,
    LS = 75,
    EO = 62,
    SV = 33,
    DK = 32,
    NH = 10,
    KR = 4,
    AG = 4,
    GR = 3,
    RG = 2,
    KM = 1, 
    NL = 0,
    JA = 0,
    PF = 0)

# %%
GGP
# Out:
# {'LH': 0.20011534025374855,
#  'VB': 0.12860438292964244,
#  'MV': 0.12341407151095732,
#  'SP': 0.07208765859284891,
#  'DR': 0.06862745098039216,
#  'CS': 0.06055363321799308,
#  'AA': 0.06055363321799308,
#  'CL': 0.05651672433679354,
#  'LN': 0.05594002306805075,
#  'PG': 0.04325259515570934,
#  'LS': 0.04325259515570934,
#  'EO': 0.03575547866205306,
#  'SV': 0.01903114186851211,
#  'DK': 0.01845444059976932,
#  'NH': 0.0057670126874279125,
#  'KR': 0.002306805074971165,
#  'AG': 0.002306805074971165,
#  'GR': 0.0017301038062283738,
#  'RG': 0.0011534025374855825,
#  'KM': 0.0005767012687427913,
#  'NL': 0.0,
#  'JA': 0.0,
#  'PF': 0.0}

# %% [markdown]
# ### Probability Distribution for Portugal Grand Prix

# %%
PGP = ProbDist(
    LH = 347,
    VB = 223,
    MV = 214,
    SP = 125,
    DR = 119,
    CS = 105,
    AA = 105,
    CL = 98,
    LN = 97,
    PG = 75,
    LS = 75,
    EO = 62,
    SV = 33,
    DK = 32,
    NH = 10,
    KR = 4,
    AG = 4,
    GR = 3,
    RG = 2,
    KM = 1, 
    NL = 0,
    JA = 0,
    PF = 0)

# %%
PGP
# Out:
# {'LH': 0.20011534025374855,
#  'VB': 0.12860438292964244,
#  'MV': 0.12341407151095732,
#  'SP': 0.07208765859284891,
#  'DR': 0.06862745098039216,
#  'CS': 0.06055363321799308,
#  'AA': 0.06055363321799308,
#  'CL': 0.05651672433679354,
#  'LN': 0.05594002306805075,
#  'PG': 0.04325259515570934,
#  'LS': 0.04325259515570934,
#  'EO': 0.03575547866205306,
#  'SV': 0.01903114186851211,
#  'DK': 0.01845444059976932,
#  'NH': 0.0057670126874279125,
#  'KR': 0.002306805074971165,
#  'AG': 0.002306805074971165,
#  'GR': 0.0017301038062283738,
#  'RG': 0.0011534025374855825,
#  'KM': 0.0005767012687427913,
#  'NL': 0.0,
#  'JA': 0.0,
#  'PF': 0.0}

# %% [markdown]
# ### Joint Probability Distribution for both Grand Prixs

# %% [markdown]
# #### Q. Probability Distribution for each F1 driver to win both the Germany and the Portugal Grand Prix?

# %%
def joint(A, B, sep=''):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b] 
                     for a in A 
                     for b in B})
                     

JP = joint(GGP, PGP, ' ')
JP
# Out:
# {'LH LH': 0.04004614940487358,
#  'LH VB': 0.025735709848088786,
#  'LH MV': 0.024697048912515698,
#  'LH SP': 0.01442584632740403,
#  'LH DR': 0.013733405703688636,
#  'LH CS': 0.012117710915019383,
#  'LH AA': 0.012117710915019383,
#  'LH CL': 0.011309863520684757,
#  'LH LN': 0.011194456750065526,
#  'LH PG': 0.008655507796442415,
#  'LH LS': 0.008655507796442415,
#  'LH EO': 0.007155219778392398,
#  'LH SV': 0.0038084234304346636,
#  'LH DK': 0.003693016659815432,
#  'LH NH': 0.0011540677061923224,
#  'LH KR': 0.000461627082476929,
#  'LH AG': 0.000461627082476929,
#  'LH GR': 0.0003462203118576967,
#  'LH RG': 0.0002308135412384645,
#  'LH KM': 0.00011540677061923224,
#  'LH NL': 0.0,
#  'LH JA': 0.0,
#  'LH PF': 0.0,
#  'VB LH': 0.025735709848088786,
#  'VB VB': 0.016539087308714118,
#  'VB MV': 0.01587159051150144,
#  'VB SP': 0.009270788850176077,
#  'VB DR': 0.008825790985367624,
#  'VB CS': 0.007787462634147904,
#  'VB AA': 0.007787462634147904,
#  'VB CL': 0.007268298458538044,
#  'VB LN': 0.007194132147736635,
#  'VB PG': 0.005562473310105644,
#  'VB LS': 0.005562473310105644,
#  'VB EO': 0.004598311269687334,
#  'VB SV': 0.002447488256446484,
#  'VB DK': 0.0023733219456450756,
#  'VB NH': 0.0007416631080140861,
#  'VB KR': 0.00029666524320563444,
#  'VB AG': 0.00029666524320563444,
#  'VB GR': 0.0002224989324042258,
#  'VB RG': 0.00014833262160281722,
#  'VB KM': 7.416631080140861e-05,
#  'VB NL': 0.0,
#  'VB JA': 0.0,
#  'VB PF': 0.0,
#  'MV LH': 0.024697048912515698,
#  'MV VB': 0.01587159051150144,
#  'MV MV': 0.015231033046911696,
#  'MV SP': 0.008896631452635338,
#  'MV DR': 0.008469593142908842,
#  'MV CS': 0.007473170420213684,
#  'MV AA': 0.007473170420213684,
#  'MV CL': 0.006974959058866104,
#  'MV LN': 0.006903786007245022,
#  'MV PG': 0.005337978871581202,
#  'MV LS': 0.005337978871581202,
#  'MV EO': 0.004412729200507127,
#  'MV SV': 0.002348710703495729,
#  'MV DK': 0.0022775376518746463,
#  'MV NH': 0.000711730516210827,
#  'MV KR': 0.0002846922064843308,
#  'MV AG': 0.0002846922064843308,
#  'MV GR': 0.0002135191548632481,
#  'MV RG': 0.0001423461032421654,
#  'MV KM': 7.11730516210827e-05,
#  'MV NL': 0.0,
#  'MV JA': 0.0,
#  'MV PF': 0.0,
#  'SP LH': 0.01442584632740403,
#  'SP VB': 0.009270788850176077,
#  'SP MV': 0.008896631452635338,
#  'SP SP': 0.005196630521399147,
#  'SP DR': 0.0049471922563719874,
#  'SP CS': 0.004365169637975282,
#  'SP AA': 0.004365169637975282,
#  'SP CL': 0.004074158328776931,
#  'SP LN': 0.004032585284605737,
#  'SP PG': 0.0031179783128394874,
#  'SP LS': 0.0031179783128394874,
#  'SP EO': 0.0025775287386139768,
#  'SP SV': 0.0013719104576493746,
#  'SP DK': 0.0013303374134781814,
#  'SP NH': 0.0004157304417119317,
#  'SP KR': 0.00016629217668477267,
#  'SP AG': 0.00016629217668477267,
#  'SP GR': 0.0001247191325135795,
#  'SP RG': 8.314608834238634e-05,
#  'SP KM': 4.157304417119317e-05,
#  'SP NL': 0.0,
#  'SP JA': 0.0,
#  'SP PF': 0.0,
#  'DR LH': 0.013733405703688636,
#  'DR VB': 0.008825790985367624,
#  'DR MV': 0.008469593142908842,
#  'DR SP': 0.0049471922563719874,
#  'DR DR': 0.004709727028066133,
#  'DR CS': 0.004155641495352469,
#  'DR AA': 0.004155641495352469,
#  'DR CL': 0.003878598728995638,
#  'DR LN': 0.003839021190944662,
#  'DR PG': 0.0029683153538231925,
#  'DR LS': 0.0029683153538231925,
#  'DR EO': 0.002453807359160506,
#  'DR SV': 0.0013060587556822047,
#  'DR DK': 0.0012664812176312289,
#  'DR NH': 0.000395775380509759,
#  'DR KR': 0.0001583101522039036,
#  'DR AG': 0.0001583101522039036,
#  'DR GR': 0.0001187326141529277,
#  'DR RG': 7.91550761019518e-05,
#  'DR KM': 3.95775380509759e-05,
#  'DR NL': 0.0,
#  'DR JA': 0.0,
#  'DR PF': 0.0,
#  'CS LH': 0.012117710915019383,
#  'CS VB': 0.007787462634147904,
#  'CS MV': 0.007473170420213684,
#  'CS SP': 0.004365169637975282,
#  'CS DR': 0.004155641495352469,
#  'CS CS': 0.0036667424958992372,
#  'CS AA': 0.0036667424958992372,
#  'CS CL': 0.0034222929961726213,
#  'CS LN': 0.0033873716390688193,
#  'CS PG': 0.002619101782785169,
#  'CS LS': 0.002619101782785169,
#  'CS EO': 0.00216512414043574,
#  'CS SV': 0.0011524047844254748,
#  'CS DK': 0.0011174834273216722,
#  'CS NH': 0.0003492135710380226,
#  'CS KR': 0.00013968542841520903,
#  'CS AG': 0.00013968542841520903,
#  'CS GR': 0.00010476407131140677,
#  'CS RG': 6.984271420760452e-05,
#  'CS KM': 3.492135710380226e-05,
#  'CS NL': 0.0,
#  'CS JA': 0.0,
#  'CS PF': 0.0,
#  'AA LH': 0.012117710915019383,
#  'AA VB': 0.007787462634147904,
#  'AA MV': 0.007473170420213684,
#  'AA SP': 0.004365169637975282,
#  'AA DR': 0.004155641495352469,
#  'AA CS': 0.0036667424958992372,
#  'AA AA': 0.0036667424958992372,
#  'AA CL': 0.0034222929961726213,
#  'AA LN': 0.0033873716390688193,
#  'AA PG': 0.002619101782785169,
#  'AA LS': 0.002619101782785169,
#  'AA EO': 0.00216512414043574,
#  'AA SV': 0.0011524047844254748,
#  'AA DK': 0.0011174834273216722,
#  'AA NH': 0.0003492135710380226,
#  'AA KR': 0.00013968542841520903,
#  'AA AG': 0.00013968542841520903,
#  'AA GR': 0.00010476407131140677,
#  'AA RG': 6.984271420760452e-05,
#  'AA KM': 3.492135710380226e-05,
#  'AA NL': 0.0,
#  'AA JA': 0.0,
#  'AA PF': 0.0,
#  'CL LH': 0.011309863520684757,
#  'CL VB': 0.007268298458538044,
#  'CL MV': 0.006974959058866104,
#  'CL SP': 0.004074158328776931,
#  'CL DR': 0.003878598728995638,
#  'CL CS': 0.0034222929961726213,
#  'CL AA': 0.0034222929961726213,
#  'CL CL': 0.0031941401297611136,
#  'CL LN': 0.0031615468631308982,
#  'CL PG': 0.0024444949972661583,
#  'CL LS': 0.0024444949972661583,
#  'CL EO': 0.0020207825310733576,
#  'CL SV': 0.0010755777987971095,
#  'CL DK': 0.0010429845321668942,
#  'CL NH': 0.0003259326663021544,
#  'CL KR': 0.00013037306652086177,
#  'CL AG': 0.00013037306652086177,
#  'CL GR': 9.777979989064634e-05,
#  'CL RG': 6.518653326043088e-05,
#  'CL KM': 3.259326663021544e-05,
#  'CL NL': 0.0,
#  'CL JA': 0.0,
#  'CL PF': 0.0,
#  'LN LH': 0.011194456750065526,
#  'LN VB': 0.007194132147736635,
#  'LN MV': 0.006903786007245022,
#  'LN SP': 0.004032585284605737,
#  'LN DR': 0.003839021190944662,
#  'LN CS': 0.0033873716390688193,
#  'LN AA': 0.0033873716390688193,
#  'LN CL': 0.0031615468631308982,
#  'LN LN': 0.0031292861808540524,
#  'LN PG': 0.0024195511707634423,
#  'LN LS': 0.0024195511707634423,
#  'LN EO': 0.0020001623011644456,
#  'LN SV': 0.0010646025151359146,
#  'LN DK': 0.0010323418328590688,
#  'LN NH': 0.000322606822768459,
#  'LN KR': 0.0001290427291073836,
#  'LN AG': 0.0001290427291073836,
#  'LN GR': 9.678204683053771e-05,
#  'LN RG': 6.45213645536918e-05,
#  'LN KM': 3.22606822768459e-05,
#  'LN NL': 0.0,
#  'LN JA': 0.0,
#  'LN PF': 0.0,
#  'PG LH': 0.008655507796442415,
#  'PG VB': 0.005562473310105644,
#  'PG MV': 0.005337978871581202,
#  'PG SP': 0.0031179783128394874,
#  'PG DR': 0.0029683153538231925,
#  'PG CS': 0.002619101782785169,
#  'PG AA': 0.002619101782785169,
#  'PG CL': 0.0024444949972661583,
#  'PG LN': 0.0024195511707634423,
#  'PG PG': 0.0018707869877036922,
#  'PG LS': 0.0018707869877036922,
#  'PG EO': 0.001546517243168386,
#  'PG SV': 0.0008231462745896247,
#  'PG DK': 0.0007982024480869087,
#  'PG NH': 0.000249438265027159,
#  'PG KR': 9.97753060108636e-05,
#  'PG AG': 9.97753060108636e-05,
#  'PG GR': 7.48314795081477e-05,
#  'PG RG': 4.98876530054318e-05,
#  'PG KM': 2.49438265027159e-05,
#  'PG NL': 0.0,
#  'PG JA': 0.0,
#  'PG PF': 0.0,
#  'LS LH': 0.008655507796442415,
#  'LS VB': 0.005562473310105644,
#  'LS MV': 0.005337978871581202,
#  'LS SP': 0.0031179783128394874,
#  'LS DR': 0.0029683153538231925,
#  'LS CS': 0.002619101782785169,
#  'LS AA': 0.002619101782785169,
#  'LS CL': 0.0024444949972661583,
#  'LS LN': 0.0024195511707634423,
#  'LS PG': 0.0018707869877036922,
#  'LS LS': 0.0018707869877036922,
#  'LS EO': 0.001546517243168386,
#  'LS SV': 0.0008231462745896247,
#  'LS DK': 0.0007982024480869087,
#  'LS NH': 0.000249438265027159,
#  'LS KR': 9.97753060108636e-05,
#  'LS AG': 9.97753060108636e-05,
#  'LS GR': 7.48314795081477e-05,
#  'LS RG': 4.98876530054318e-05,
#  'LS KM': 2.49438265027159e-05,
#  'LS NL': 0.0,
#  'LS JA': 0.0,
#  'LS PF': 0.0,
#  'EO LH': 0.007155219778392398,
#  'EO VB': 0.004598311269687334,
#  'EO MV': 0.004412729200507127,
#  'EO SP': 0.0025775287386139768,
#  'EO DR': 0.002453807359160506,
#  'EO CS': 0.00216512414043574,
#  'EO AA': 0.00216512414043574,
#  'EO CL': 0.0020207825310733576,
#  'EO LN': 0.0020001623011644456,
#  'EO PG': 0.001546517243168386,
#  'EO LS': 0.001546517243168386,
#  'EO EO': 0.0012784542543525324,
#  'EO SV': 0.0006804675869940898,
#  'EO DK': 0.000659847357085178,
#  'EO NH': 0.00020620229908911814,
#  'EO KR': 8.248091963564725e-05,
#  'EO AG': 8.248091963564725e-05,
#  'EO GR': 6.186068972673544e-05,
#  'EO RG': 4.1240459817823626e-05,
#  'EO KM': 2.0620229908911813e-05,
#  'EO NL': 0.0,
#  'EO JA': 0.0,
#  'EO PF': 0.0,
#  'SV LH': 0.0038084234304346636,
#  'SV VB': 0.002447488256446484,
#  'SV MV': 0.002348710703495729,
#  'SV SP': 0.0013719104576493746,
#  'SV DR': 0.0013060587556822047,
#  'SV CS': 0.0011524047844254748,
#  'SV AA': 0.0011524047844254748,
#  'SV CL': 0.0010755777987971095,
#  'SV LN': 0.0010646025151359146,
#  'SV PG': 0.0008231462745896247,
#  'SV LS': 0.0008231462745896247,
#  'SV EO': 0.0006804675869940898,
#  'SV SV': 0.00036218436081943486,
#  'SV DK': 0.00035120907715823987,
#  'SV NH': 0.00010975283661194997,
#  'SV KR': 4.3901134644779984e-05,
#  'SV AG': 4.3901134644779984e-05,
#  'SV GR': 3.292585098358499e-05,
#  'SV RG': 2.1950567322389992e-05,
#  'SV KM': 1.0975283661194996e-05,
#  'SV NL': 0.0,
#  'SV JA': 0.0,
#  'SV PF': 0.0,
#  'DK LH': 0.003693016659815432,
#  'DK VB': 0.0023733219456450756,
#  'DK MV': 0.0022775376518746463,
#  'DK SP': 0.0013303374134781814,
#  'DK DR': 0.0012664812176312289,
#  'DK CS': 0.0011174834273216722,
#  'DK AA': 0.0011174834273216722,
#  'DK CL': 0.0010429845321668942,
#  'DK LN': 0.0010323418328590688,
#  'DK PG': 0.0007982024480869087,
#  'DK LS': 0.0007982024480869087,
#  'DK EO': 0.000659847357085178,
#  'DK SV': 0.00035120907715823987,
#  'DK DK': 0.0003405663778504144,
#  'DK NH': 0.00010642699307825452,
#  'DK KR': 4.25707972313018e-05,
#  'DK AG': 4.25707972313018e-05,
#  'DK GR': 3.192809792347635e-05,
#  'DK RG': 2.12853986156509e-05,
#  'DK KM': 1.064269930782545e-05,
#  'DK NL': 0.0,
#  'DK JA': 0.0,
#  'DK PF': 0.0,
#  'NH LH': 0.0011540677061923224,
#  'NH VB': 0.0007416631080140861,
#  'NH MV': 0.000711730516210827,
#  'NH SP': 0.0004157304417119317,
#  'NH DR': 0.000395775380509759,
#  'NH CS': 0.0003492135710380226,
#  'NH AA': 0.0003492135710380226,
#  'NH CL': 0.0003259326663021544,
#  'NH LN': 0.000322606822768459,
#  'NH PG': 0.000249438265027159,
#  'NH LS': 0.000249438265027159,
#  'NH EO': 0.00020620229908911814,
#  'NH SV': 0.00010975283661194997,
#  'NH DK': 0.00010642699307825452,
#  'NH NH': 3.3258435336954533e-05,
#  'NH KR': 1.3303374134781815e-05,
#  'NH AG': 1.3303374134781815e-05,
#  'NH GR': 9.977530601086361e-06,
#  'NH RG': 6.651687067390907e-06,
#  'NH KM': 3.3258435336954537e-06,
#  'NH NL': 0.0,
#  'NH JA': 0.0,
#  'NH PF': 0.0,
#  'KR LH': 0.000461627082476929,
#  'KR VB': 0.00029666524320563444,
#  'KR MV': 0.0002846922064843308,
#  'KR SP': 0.00016629217668477267,
#  'KR DR': 0.0001583101522039036,
#  'KR CS': 0.00013968542841520903,
#  'KR AA': 0.00013968542841520903,
#  'KR CL': 0.00013037306652086177,
#  'KR LN': 0.0001290427291073836,
#  'KR PG': 9.97753060108636e-05,
#  'KR LS': 9.97753060108636e-05,
#  'KR EO': 8.248091963564725e-05,
#  'KR SV': 4.3901134644779984e-05,
#  'KR DK': 4.25707972313018e-05,
#  'KR NH': 1.3303374134781815e-05,
#  'KR KR': 5.321349653912725e-06,
#  'KR AG': 5.321349653912725e-06,
#  'KR GR': 3.991012240434544e-06,
#  'KR RG': 2.6606748269563626e-06,
#  'KR KM': 1.3303374134781813e-06,
#  'KR NL': 0.0,
#  'KR JA': 0.0,
#  'KR PF': 0.0,
#  'AG LH': 0.000461627082476929,
#  'AG VB': 0.00029666524320563444,
#  'AG MV': 0.0002846922064843308,
#  'AG SP': 0.00016629217668477267,
#  'AG DR': 0.0001583101522039036,
#  'AG CS': 0.00013968542841520903,
#  'AG AA': 0.00013968542841520903,
#  'AG CL': 0.00013037306652086177,
#  'AG LN': 0.0001290427291073836,
#  'AG PG': 9.97753060108636e-05,
#  'AG LS': 9.97753060108636e-05,
#  'AG EO': 8.248091963564725e-05,
#  'AG SV': 4.3901134644779984e-05,
#  'AG DK': 4.25707972313018e-05,
#  'AG NH': 1.3303374134781815e-05,
#  'AG KR': 5.321349653912725e-06,
#  'AG AG': 5.321349653912725e-06,
#  'AG GR': 3.991012240434544e-06,
#  'AG RG': 2.6606748269563626e-06,
#  'AG KM': 1.3303374134781813e-06,
#  'AG NL': 0.0,
#  'AG JA': 0.0,
#  'AG PF': 0.0,
#  'GR LH': 0.0003462203118576967,
#  'GR VB': 0.0002224989324042258,
#  'GR MV': 0.0002135191548632481,
#  'GR SP': 0.0001247191325135795,
#  'GR DR': 0.0001187326141529277,
#  'GR CS': 0.00010476407131140677,
#  'GR AA': 0.00010476407131140677,
#  'GR CL': 9.777979989064634e-05,
#  'GR LN': 9.678204683053771e-05,
#  'GR PG': 7.48314795081477e-05,
#  'GR LS': 7.48314795081477e-05,
#  'GR EO': 6.186068972673544e-05,
#  'GR SV': 3.292585098358499e-05,
#  'GR DK': 3.192809792347635e-05,
#  'GR NH': 9.977530601086361e-06,
#  'GR KR': 3.991012240434544e-06,
#  'GR AG': 3.991012240434544e-06,
#  'GR GR': 2.993259180325908e-06,
#  'GR RG': 1.995506120217272e-06,
#  'GR KM': 9.97753060108636e-07,
#  'GR NL': 0.0,
#  'GR JA': 0.0,
#  'GR PF': 0.0,
#  'RG LH': 0.0002308135412384645,
#  'RG VB': 0.00014833262160281722,
#  'RG MV': 0.0001423461032421654,
#  'RG SP': 8.314608834238634e-05,
#  'RG DR': 7.91550761019518e-05,
#  'RG CS': 6.984271420760452e-05,
#  'RG AA': 6.984271420760452e-05,
#  'RG CL': 6.518653326043088e-05,
#  'RG LN': 6.45213645536918e-05,
#  'RG PG': 4.98876530054318e-05,
#  'RG LS': 4.98876530054318e-05,
#  'RG EO': 4.1240459817823626e-05,
#  'RG SV': 2.1950567322389992e-05,
#  'RG DK': 2.12853986156509e-05,
#  'RG NH': 6.651687067390907e-06,
#  'RG KR': 2.6606748269563626e-06,
#  'RG AG': 2.6606748269563626e-06,
#  'RG GR': 1.995506120217272e-06,
#  'RG RG': 1.3303374134781813e-06,
#  'RG KM': 6.651687067390907e-07,
#  'RG NL': 0.0,
#  'RG JA': 0.0,
#  'RG PF': 0.0,
#  'KM LH': 0.00011540677061923224,
#  'KM VB': 7.416631080140861e-05,
#  'KM MV': 7.11730516210827e-05,
#  'KM SP': 4.157304417119317e-05,
#  'KM DR': 3.95775380509759e-05,
#  'KM CS': 3.492135710380226e-05,
#  'KM AA': 3.492135710380226e-05,
#  'KM CL': 3.259326663021544e-05,
#  'KM LN': 3.22606822768459e-05,
#  'KM PG': 2.49438265027159e-05,
#  'KM LS': 2.49438265027159e-05,
#  'KM EO': 2.0620229908911813e-05,
#  'KM SV': 1.0975283661194996e-05,
#  'KM DK': 1.064269930782545e-05,
#  'KM NH': 3.3258435336954537e-06,
#  'KM KR': 1.3303374134781813e-06,
#  'KM AG': 1.3303374134781813e-06,
#  'KM GR': 9.97753060108636e-07,
#  'KM RG': 6.651687067390907e-07,
#  'KM KM': 3.325843533695453e-07,
#  'KM NL': 0.0,
#  'KM JA': 0.0,
#  'KM PF': 0.0,
#  'NL LH': 0.0,
#  'NL VB': 0.0,
#  'NL MV': 0.0,
#  'NL SP': 0.0,
#  'NL DR': 0.0,
#  'NL CS': 0.0,
#  'NL AA': 0.0,
#  'NL CL': 0.0,
#  'NL LN': 0.0,
#  'NL PG': 0.0,
#  'NL LS': 0.0,
#  'NL EO': 0.0,
#  'NL SV': 0.0,
#  'NL DK': 0.0,
#  'NL NH': 0.0,
#  'NL KR': 0.0,
#  'NL AG': 0.0,
#  'NL GR': 0.0,
#  'NL RG': 0.0,
#  'NL KM': 0.0,
#  'NL NL': 0.0,
#  'NL JA': 0.0,
#  'NL PF': 0.0,
#  'JA LH': 0.0,
#  'JA VB': 0.0,
#  'JA MV': 0.0,
#  'JA SP': 0.0,
#  'JA DR': 0.0,
#  'JA CS': 0.0,
#  'JA AA': 0.0,
#  'JA CL': 0.0,
#  'JA LN': 0.0,
#  'JA PG': 0.0,
#  'JA LS': 0.0,
#  'JA EO': 0.0,
#  'JA SV': 0.0,
#  'JA DK': 0.0,
#  'JA NH': 0.0,
#  'JA KR': 0.0,
#  'JA AG': 0.0,
#  'JA GR': 0.0,
#  'JA RG': 0.0,
#  'JA KM': 0.0,
#  'JA NL': 0.0,
#  'JA JA': 0.0,
#  'JA PF': 0.0,
#  'PF LH': 0.0,
#  'PF VB': 0.0,
#  'PF MV': 0.0,
#  'PF SP': 0.0,
#  'PF DR': 0.0,
#  'PF CS': 0.0,
#  'PF AA': 0.0,
#  'PF CL': 0.0,
#  'PF LN': 0.0,
#  'PF PG': 0.0,
#  'PF LS': 0.0,
#  'PF EO': 0.0,
#  'PF SV': 0.0,
#  'PF DK': 0.0,
#  'PF NH': 0.0,
#  'PF KR': 0.0,
#  'PF AG': 0.0,
#  'PF GR': 0.0,
#  'PF RG': 0.0,
#  'PF KM': 0.0,
#  'PF NL': 0.0,
#  'PF JA': 0.0,
#  'PF PF': 0.0}

# %% [markdown]
# #### Q. Probability for Mercedes to win both races?

# %%
def both_mercedes(outcome): return 'LH VB' in outcome or 'VB LH' in outcome or 'LH LH' in outcome or 'VB VB' in outcome

# %%
p(both_mercedes, JP)
# Out:
# 0.10805665640976528

# %% [markdown]
# #### Q. Probability for Mercedes to win atleast one races?

# %%
def atleast_one_mercedes(outcome): return 'LH' in outcome or 'VB' in outcome

# %%
p(atleast_one_mercedes, JP)
# Out:
# 0.549382789957017

# %% [markdown]
# ####  Q.2: If Mercedes wins the first race, what is the probability that Mercedes wins the next one?

# %%
def mercedes_first(outcome): return outcome.startswith('LH') or outcome.startswith('VB')
def mercedes_second(outcome): return outcome.endswith('LH') or outcome.endswith('VB')

# %%
p(mercedes_second, such_that(mercedes_first, JP))
# Out:
# 0.32871972318339093

# %%
def atleast_one_mercedes(outcome): return 'LH' in outcome or 'VB' in outcome
def both_mercedes(outcome): return 'LH VB' in outcome or 'VB LH' in outcome or 'LH LH' in outcome or 'VB VB' in outcome

# %%
p(both_mercedes, such_that(atleast_one_mercedes, JP))
# Out:
# 0.19668737060041416

# %% [markdown]
# #### For Ferrari,

# %%
def both_ferrari(outcome): return 'CL SV' in outcome or 'SV CL' in outcome or 'CL CL' in outcome or 'SV SV' in outcome

# %%
p(both_ferrari, JP)
# Out:
# 0.005707480088174767

# %%
def atleast_one_ferrari(outcome): return 'CL' in outcome or 'SV' in outcome

# %%
p(atleast_one_ferrari, JP)
# Out:
# 0.14538825232243657

# %%
def ferrari_first(outcome): return outcome.startswith('CL') or outcome.startswith('SV')
def ferrari_second(outcome): return outcome.endswith('CL') or outcome.endswith('SV')

# %%
p(ferrari_second, such_that(ferrari_first, JP))
# Out:
# 0.07554786620530564

# %%
def atleast_one_ferrari(outcome): return 'CL' in outcome or 'SV' in outcome
def both_ferrari(outcome): return 'CL SV' in outcome or 'SV CL' in outcome or 'CL CL' in outcome or 'SV SV' in outcome

# %%
p(both_ferrari, such_that(atleast_one_ferrari, JP))
# Out:
# 0.03925681750074919

# %% [markdown]
# #### For McLaren,

# %%
def both_mclaren(outcome): return 'CS LN' in outcome or 'LN CS' in outcome or 'CS CS' in outcome or 'LN LN' in outcome

# %%
p(both_mclaren, JP)
# Out:
# 0.013570771954890927

# %%
def atleast_one_mclaren(outcome): return 'CS' in outcome or 'LN' in outcome

# %%
p(atleast_one_mclaren, JP)
# Out:
# 0.21941654061719706

# %%
def mclaren_first(outcome): return outcome.startswith('CS') or outcome.startswith('LN')
def mclaren_second(outcome): return outcome.endswith('CS') or outcome.endswith('LN')

# %%
p(mclaren_second, such_that(mclaren_first, JP))
# Out:
# 0.11649365628604386

# %%
def atleast_one_mclaren(outcome): return 'CS' in outcome or 'LN' in outcome
def both_mclaren(outcome): return 'CS LN' in outcome or 'LN CS' in outcome or 'CS CS' in outcome or 'LN LN' in outcome

# %%
p(both_mclaren, such_that(atleast_one_mclaren, JP))
# Out:
# 0.06184935701163498

# %% [markdown]
# #### For Alfa Romeo,

# %%
def both_alfaromeo(outcome): return 'KR AG' in outcome or 'AG KR' in outcome or 'KR KR' in outcome or 'AG AG' in outcome

# %%
p(both_alfaromeo, JP) * 100
# Out:
# 0.00212853986156509

# %%
def atleast_one_alfaromeo(outcome): return 'KR' in outcome or 'AG' in outcome

# %%
p(atleast_one_alfaromeo, JP)
# Out:
# 0.00920593490126901

# %%
def alfaromeo_first(outcome): return outcome.startswith('KR') or outcome.startswith('AG')
def alfaromeo_second(outcome): return outcome.endswith('KR') or outcome.endswith('AG')

# %%
p(alfaromeo_second, such_that(alfaromeo_first, JP))
# Out:
# 0.004613610149942333

# %%
def atleast_one_alfaromeo(outcome): return 'KR' in outcome or 'AG' in outcome
def both_alfaromeo(outcome): return 'KR AG' in outcome or 'AG KR' in outcome or 'KR KR' in outcome or 'AG AG' in outcome

# %%
p(both_alfaromeo, such_that(atleast_one_alfaromeo, JP))
# Out:
# 0.0023121387283237004

# %% [markdown]
# #### Q.3: Considering Weather conditions

# %%
Weather = ProbDist(Rain=0.2, Sun=0.2, Clouds=0.2, Snow=0.2, Fog=0.2)

# %% [markdown]
# #### Joint Probability Distribution for Germany GP, Portugal GP and Weather conditions

# %%
def joint(A, B, C, D ,sep=''):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b + sep + c + sep + d: A[a] * B[b] * C[c] * D[d]
                    for a in A
                    for b in B
                    for c in C
                    for d in D})

WJ = joint(GGP, Weather ,PGP, Weather,'-')
WJ
# Out:
# {'LH-Rain-LH-Rain': 0.0016018459761949723,
#  'LH-Rain-LH-Sun': 0.0016018459761949723,
#  'LH-Rain-LH-Clouds': 0.0016018459761949723,
#  'LH-Rain-LH-Snow': 0.0016018459761949723,
#  'LH-Rain-LH-Fog': 0.0016018459761949723,
#  'LH-Rain-VB-Rain': 0.0010294283939235702,
#  'LH-Rain-VB-Sun': 0.0010294283939235702,
#  'LH-Rain-VB-Clouds': 0.0010294283939235702,
#  'LH-Rain-VB-Snow': 0.0010294283939235702,
#  'LH-Rain-VB-Fog': 0.0010294283939235702,
#  'LH-Rain-MV-Rain': 0.0009878819565006455,
#  'LH-Rain-MV-Sun': 0.0009878819565006455,
#  'LH-Rain-MV-Clouds': 0.0009878819565006455,
#  'LH-Rain-MV-Snow': 0.0009878819565006455,
#  'LH-Rain-MV-Fog': 0.0009878819565006455,
#  'LH-Rain-SP-Rain': 0.0005770338530961715,
#  'LH-Rain-SP-Sun': 0.0005770338530961715,
#  'LH-Rain-SP-Clouds': 0.0005770338530961715,
#  'LH-Rain-SP-Snow': 0.0005770338530961715,
#  'LH-Rain-SP-Fog': 0.0005770338530961715,
#  'LH-Rain-DR-Rain': 0.0005493362281475554,
#  'LH-Rain-DR-Sun': 0.0005493362281475554,
#  'LH-Rain-DR-Clouds': 0.0005493362281475554,
#  'LH-Rain-DR-Snow': 0.0005493362281475554,
#  'LH-Rain-DR-Fog': 0.0005493362281475554,
#  'LH-Rain-CS-Rain': 0.00048470843660078415,
#  'LH-Rain-CS-Sun': 0.00048470843660078415,
#  'LH-Rain-CS-Clouds': 0.00048470843660078415,
#  'LH-Rain-CS-Snow': 0.00048470843660078415,
#  'LH-Rain-CS-Fog': 0.00048470843660078415,
#  'LH-Rain-AA-Rain': 0.00048470843660078415,
#  'LH-Rain-AA-Sun': 0.00048470843660078415,
#  'LH-Rain-AA-Clouds': 0.00048470843660078415,
#  'LH-Rain-AA-Snow': 0.00048470843660078415,
#  'LH-Rain-AA-Fog': 0.00048470843660078415,
#  'LH-Rain-CL-Rain': 0.00045239454082739855,
#  'LH-Rain-CL-Sun': 0.00045239454082739855,
#  'LH-Rain-CL-Clouds': 0.00045239454082739855,
#  'LH-Rain-CL-Snow': 0.00045239454082739855,
#  'LH-Rain-CL-Fog': 0.00045239454082739855,
#  'LH-Rain-LN-Rain': 0.0004477782700026291,
#  'LH-Rain-LN-Sun': 0.0004477782700026291,
#  'LH-Rain-LN-Clouds': 0.0004477782700026291,
#  'LH-Rain-LN-Snow': 0.0004477782700026291,
#  'LH-Rain-LN-Fog': 0.0004477782700026291,
#  'LH-Rain-PG-Rain': 0.0003462203118577029,
#  'LH-Rain-PG-Sun': 0.0003462203118577029,
#  'LH-Rain-PG-Clouds': 0.0003462203118577029,
#  'LH-Rain-PG-Snow': 0.0003462203118577029,
#  'LH-Rain-PG-Fog': 0.0003462203118577029,
#  'LH-Rain-LS-Rain': 0.0003462203118577029,
#  'LH-Rain-LS-Sun': 0.0003462203118577029,
#  'LH-Rain-LS-Clouds': 0.0003462203118577029,
#  'LH-Rain-LS-Snow': 0.0003462203118577029,
#  'LH-Rain-LS-Fog': 0.0003462203118577029,
#  'LH-Rain-EO-Rain': 0.0002862087911357011,
#  'LH-Rain-EO-Sun': 0.0002862087911357011,
#  'LH-Rain-EO-Clouds': 0.0002862087911357011,
#  'LH-Rain-EO-Snow': 0.0002862087911357011,
#  'LH-Rain-EO-Fog': 0.0002862087911357011,
#  'LH-Rain-SV-Rain': 0.00015233693721738932,
#  'LH-Rain-SV-Sun': 0.00015233693721738932,
#  'LH-Rain-SV-Clouds': 0.00015233693721738932,
#  'LH-Rain-SV-Snow': 0.00015233693721738932,
#  'LH-Rain-SV-Fog': 0.00015233693721738932,
#  'LH-Rain-DK-Rain': 0.00014772066639261993,
#  'LH-Rain-DK-Sun': 0.00014772066639261993,
#  'LH-Rain-DK-Clouds': 0.00014772066639261993,
#  'LH-Rain-DK-Snow': 0.00014772066639261993,
#  'LH-Rain-DK-Fog': 0.00014772066639261993,
#  'LH-Rain-NH-Rain': 4.616270824769373e-05,
#  'LH-Rain-NH-Sun': 4.616270824769373e-05,
#  'LH-Rain-NH-Clouds': 4.616270824769373e-05,
#  'LH-Rain-NH-Snow': 4.616270824769373e-05,
#  'LH-Rain-NH-Fog': 4.616270824769373e-05,
#  'LH-Rain-KR-Rain': 1.8465083299077492e-05,
#  'LH-Rain-KR-Sun': 1.8465083299077492e-05,
#  'LH-Rain-KR-Clouds': 1.8465083299077492e-05,
#  'LH-Rain-KR-Snow': 1.8465083299077492e-05,
#  'LH-Rain-KR-Fog': 1.8465083299077492e-05,
#  'LH-Rain-AG-Rain': 1.8465083299077492e-05,
#  'LH-Rain-AG-Sun': 1.8465083299077492e-05,
#  'LH-Rain-AG-Clouds': 1.8465083299077492e-05,
#  'LH-Rain-AG-Snow': 1.8465083299077492e-05,
#  'LH-Rain-AG-Fog': 1.8465083299077492e-05,
#  'LH-Rain-GR-Rain': 1.3848812474308116e-05,
#  'LH-Rain-GR-Sun': 1.3848812474308116e-05,
#  'LH-Rain-GR-Clouds': 1.3848812474308116e-05,
#  'LH-Rain-GR-Snow': 1.3848812474308116e-05,
#  'LH-Rain-GR-Fog': 1.3848812474308116e-05,
#  'LH-Rain-RG-Rain': 9.232541649538746e-06,
#  'LH-Rain-RG-Sun': 9.232541649538746e-06,
#  'LH-Rain-RG-Clouds': 9.232541649538746e-06,
#  'LH-Rain-RG-Snow': 9.232541649538746e-06,
#  'LH-Rain-RG-Fog': 9.232541649538746e-06,
#  'LH-Rain-KM-Rain': 4.616270824769373e-06,
#  'LH-Rain-KM-Sun': 4.616270824769373e-06,
#  'LH-Rain-KM-Clouds': 4.616270824769373e-06,
#  'LH-Rain-KM-Snow': 4.616270824769373e-06,
#  'LH-Rain-KM-Fog': 4.616270824769373e-06,
#  'LH-Rain-NL-Rain': 0.0,
#  'LH-Rain-NL-Sun': 0.0,
#  'LH-Rain-NL-Clouds': 0.0,
#  'LH-Rain-NL-Snow': 0.0,
#  'LH-Rain-NL-Fog': 0.0,
#  'LH-Rain-JA-Rain': 0.0,
#  'LH-Rain-JA-Sun': 0.0,
#  'LH-Rain-JA-Clouds': 0.0,
#  'LH-Rain-JA-Snow': 0.0,
#  'LH-Rain-JA-Fog': 0.0,
#  'LH-Rain-PF-Rain': 0.0,
#  'LH-Rain-PF-Sun': 0.0,
#  'LH-Rain-PF-Clouds': 0.0,
#  'LH-Rain-PF-Snow': 0.0,
#  'LH-Rain-PF-Fog': 0.0,
#  'LH-Sun-LH-Rain': 0.0016018459761949723,
#  'LH-Sun-LH-Sun': 0.0016018459761949723,
#  'LH-Sun-LH-Clouds': 0.0016018459761949723,
#  'LH-Sun-LH-Snow': 0.0016018459761949723,
#  'LH-Sun-LH-Fog': 0.0016018459761949723,
#  'LH-Sun-VB-Rain': 0.0010294283939235702,
#  'LH-Sun-VB-Sun': 0.0010294283939235702,
#  'LH-Sun-VB-Clouds': 0.0010294283939235702,
#  'LH-Sun-VB-Snow': 0.0010294283939235702,
#  'LH-Sun-VB-Fog': 0.0010294283939235702,
#  'LH-Sun-MV-Rain': 0.0009878819565006455,
#  'LH-Sun-MV-Sun': 0.0009878819565006455,
#  'LH-Sun-MV-Clouds': 0.0009878819565006455,
#  'LH-Sun-MV-Snow': 0.0009878819565006455,
#  'LH-Sun-MV-Fog': 0.0009878819565006455,
#  'LH-Sun-SP-Rain': 0.0005770338530961715,
#  'LH-Sun-SP-Sun': 0.0005770338530961715,
#  'LH-Sun-SP-Clouds': 0.0005770338530961715,
#  'LH-Sun-SP-Snow': 0.0005770338530961715,
#  'LH-Sun-SP-Fog': 0.0005770338530961715,
#  'LH-Sun-DR-Rain': 0.0005493362281475554,
#  'LH-Sun-DR-Sun': 0.0005493362281475554,
#  'LH-Sun-DR-Clouds': 0.0005493362281475554,
#  'LH-Sun-DR-Snow': 0.0005493362281475554,
#  'LH-Sun-DR-Fog': 0.0005493362281475554,
#  'LH-Sun-CS-Rain': 0.00048470843660078415,
#  'LH-Sun-CS-Sun': 0.00048470843660078415,
#  'LH-Sun-CS-Clouds': 0.00048470843660078415,
#  'LH-Sun-CS-Snow': 0.00048470843660078415,
#  'LH-Sun-CS-Fog': 0.00048470843660078415,
#  'LH-Sun-AA-Rain': 0.00048470843660078415,
#  'LH-Sun-AA-Sun': 0.00048470843660078415,
#  'LH-Sun-AA-Clouds': 0.00048470843660078415,
#  'LH-Sun-AA-Snow': 0.00048470843660078415,
#  'LH-Sun-AA-Fog': 0.00048470843660078415,
#  'LH-Sun-CL-Rain': 0.00045239454082739855,
#  'LH-Sun-CL-Sun': 0.00045239454082739855,
#  'LH-Sun-CL-Clouds': 0.00045239454082739855,
#  'LH-Sun-CL-Snow': 0.00045239454082739855,
#  'LH-Sun-CL-Fog': 0.00045239454082739855,
#  'LH-Sun-LN-Rain': 0.0004477782700026291,
#  'LH-Sun-LN-Sun': 0.0004477782700026291,
#  'LH-Sun-LN-Clouds': 0.0004477782700026291,
#  'LH-Sun-LN-Snow': 0.0004477782700026291,
#  'LH-Sun-LN-Fog': 0.0004477782700026291,
#  'LH-Sun-PG-Rain': 0.0003462203118577029,
#  'LH-Sun-PG-Sun': 0.0003462203118577029,
#  'LH-Sun-PG-Clouds': 0.0003462203118577029,
#  'LH-Sun-PG-Snow': 0.0003462203118577029,
#  'LH-Sun-PG-Fog': 0.0003462203118577029,
#  'LH-Sun-LS-Rain': 0.0003462203118577029,
#  'LH-Sun-LS-Sun': 0.0003462203118577029,
#  'LH-Sun-LS-Clouds': 0.0003462203118577029,
#  'LH-Sun-LS-Snow': 0.0003462203118577029,
#  'LH-Sun-LS-Fog': 0.0003462203118577029,
#  'LH-Sun-EO-Rain': 0.0002862087911357011,
#  'LH-Sun-EO-Sun': 0.0002862087911357011,
#  'LH-Sun-EO-Clouds': 0.0002862087911357011,
#  'LH-Sun-EO-Snow': 0.0002862087911357011,
#  'LH-Sun-EO-Fog': 0.0002862087911357011,
#  'LH-Sun-SV-Rain': 0.00015233693721738932,
#  'LH-Sun-SV-Sun': 0.00015233693721738932,
#  'LH-Sun-SV-Clouds': 0.00015233693721738932,
#  'LH-Sun-SV-Snow': 0.00015233693721738932,
#  'LH-Sun-SV-Fog': 0.00015233693721738932,
#  'LH-Sun-DK-Rain': 0.00014772066639261993,
#  'LH-Sun-DK-Sun': 0.00014772066639261993,
#  'LH-Sun-DK-Clouds': 0.00014772066639261993,
#  'LH-Sun-DK-Snow': 0.00014772066639261993,
#  'LH-Sun-DK-Fog': 0.00014772066639261993,
#  'LH-Sun-NH-Rain': 4.616270824769373e-05,
#  'LH-Sun-NH-Sun': 4.616270824769373e-05,
#  'LH-Sun-NH-Clouds': 4.616270824769373e-05,
#  'LH-Sun-NH-Snow': 4.616270824769373e-05,
#  'LH-Sun-NH-Fog': 4.616270824769373e-05,
#  'LH-Sun-KR-Rain': 1.8465083299077492e-05,
#  'LH-Sun-KR-Sun': 1.8465083299077492e-05,
#  'LH-Sun-KR-Clouds': 1.8465083299077492e-05,
#  'LH-Sun-KR-Snow': 1.8465083299077492e-05,
#  'LH-Sun-KR-Fog': 1.8465083299077492e-05,
#  'LH-Sun-AG-Rain': 1.8465083299077492e-05,
#  'LH-Sun-AG-Sun': 1.8465083299077492e-05,
#  'LH-Sun-AG-Clouds': 1.8465083299077492e-05,
#  'LH-Sun-AG-Snow': 1.8465083299077492e-05,
#  'LH-Sun-AG-Fog': 1.8465083299077492e-05,
#  'LH-Sun-GR-Rain': 1.3848812474308116e-05,
#  'LH-Sun-GR-Sun': 1.3848812474308116e-05,
#  'LH-Sun-GR-Clouds': 1.3848812474308116e-05,
#  'LH-Sun-GR-Snow': 1.3848812474308116e-05,
#  'LH-Sun-GR-Fog': 1.3848812474308116e-05,
#  'LH-Sun-RG-Rain': 9.232541649538746e-06,
#  'LH-Sun-RG-Sun': 9.232541649538746e-06,
#  'LH-Sun-RG-Clouds': 9.232541649538746e-06,
#  'LH-Sun-RG-Snow': 9.232541649538746e-06,
#  'LH-Sun-RG-Fog': 9.232541649538746e-06,
#  'LH-Sun-KM-Rain': 4.616270824769373e-06,
#  'LH-Sun-KM-Sun': 4.616270824769373e-06,
#  'LH-Sun-KM-Clouds': 4.616270824769373e-06,
#  'LH-Sun-KM-Snow': 4.616270824769373e-06,
#  'LH-Sun-KM-Fog': 4.616270824769373e-06,
#  'LH-Sun-NL-Rain': 0.0,
#  'LH-Sun-NL-Sun': 0.0,
#  'LH-Sun-NL-Clouds': 0.0,
#  'LH-Sun-NL-Snow': 0.0,
#  'LH-Sun-NL-Fog': 0.0,
#  'LH-Sun-JA-Rain': 0.0,
#  'LH-Sun-JA-Sun': 0.0,
#  'LH-Sun-JA-Clouds': 0.0,
#  'LH-Sun-JA-Snow': 0.0,
#  'LH-Sun-JA-Fog': 0.0,
#  'LH-Sun-PF-Rain': 0.0,
#  'LH-Sun-PF-Sun': 0.0,
#  'LH-Sun-PF-Clouds': 0.0,
#  'LH-Sun-PF-Snow': 0.0,
#  'LH-Sun-PF-Fog': 0.0,
#  'LH-Clouds-LH-Rain': 0.0016018459761949723,
#  'LH-Clouds-LH-Sun': 0.0016018459761949723,
#  'LH-Clouds-LH-Clouds': 0.0016018459761949723,
#  'LH-Clouds-LH-Snow': 0.0016018459761949723,
#  'LH-Clouds-LH-Fog': 0.0016018459761949723,
#  'LH-Clouds-VB-Rain': 0.0010294283939235702,
#  'LH-Clouds-VB-Sun': 0.0010294283939235702,
#  'LH-Clouds-VB-Clouds': 0.0010294283939235702,
#  'LH-Clouds-VB-Snow': 0.0010294283939235702,
#  'LH-Clouds-VB-Fog': 0.0010294283939235702,
#  'LH-Clouds-MV-Rain': 0.0009878819565006455,
#  'LH-Clouds-MV-Sun': 0.0009878819565006455,
#  'LH-Clouds-MV-Clouds': 0.0009878819565006455,
#  'LH-Clouds-MV-Snow': 0.0009878819565006455,
#  'LH-Clouds-MV-Fog': 0.0009878819565006455,
#  'LH-Clouds-SP-Rain': 0.0005770338530961715,
#  'LH-Clouds-SP-Sun': 0.0005770338530961715,
#  'LH-Clouds-SP-Clouds': 0.0005770338530961715,
#  'LH-Clouds-SP-Snow': 0.0005770338530961715,
#  'LH-Clouds-SP-Fog': 0.0005770338530961715,
#  'LH-Clouds-DR-Rain': 0.0005493362281475554,
#  'LH-Clouds-DR-Sun': 0.0005493362281475554,
#  'LH-Clouds-DR-Clouds': 0.0005493362281475554,
#  'LH-Clouds-DR-Snow': 0.0005493362281475554,
#  'LH-Clouds-DR-Fog': 0.0005493362281475554,
#  'LH-Clouds-CS-Rain': 0.00048470843660078415,
#  'LH-Clouds-CS-Sun': 0.00048470843660078415,
#  'LH-Clouds-CS-Clouds': 0.00048470843660078415,
#  'LH-Clouds-CS-Snow': 0.00048470843660078415,
#  'LH-Clouds-CS-Fog': 0.00048470843660078415,
#  'LH-Clouds-AA-Rain': 0.00048470843660078415,
#  'LH-Clouds-AA-Sun': 0.00048470843660078415,
#  'LH-Clouds-AA-Clouds': 0.00048470843660078415,
#  'LH-Clouds-AA-Snow': 0.00048470843660078415,
#  'LH-Clouds-AA-Fog': 0.00048470843660078415,
#  'LH-Clouds-CL-Rain': 0.00045239454082739855,
#  'LH-Clouds-CL-Sun': 0.00045239454082739855,
#  'LH-Clouds-CL-Clouds': 0.00045239454082739855,
#  'LH-Clouds-CL-Snow': 0.00045239454082739855,
#  'LH-Clouds-CL-Fog': 0.00045239454082739855,
#  'LH-Clouds-LN-Rain': 0.0004477782700026291,
#  'LH-Clouds-LN-Sun': 0.0004477782700026291,
#  'LH-Clouds-LN-Clouds': 0.0004477782700026291,
#  'LH-Clouds-LN-Snow': 0.0004477782700026291,
#  'LH-Clouds-LN-Fog': 0.0004477782700026291,
#  'LH-Clouds-PG-Rain': 0.0003462203118577029,
#  'LH-Clouds-PG-Sun': 0.0003462203118577029,
#  'LH-Clouds-PG-Clouds': 0.0003462203118577029,
#  'LH-Clouds-PG-Snow': 0.0003462203118577029,
#  'LH-Clouds-PG-Fog': 0.0003462203118577029,
#  'LH-Clouds-LS-Rain': 0.0003462203118577029,
#  'LH-Clouds-LS-Sun': 0.0003462203118577029,
#  'LH-Clouds-LS-Clouds': 0.0003462203118577029,
#  'LH-Clouds-LS-Snow': 0.0003462203118577029,
#  'LH-Clouds-LS-Fog': 0.0003462203118577029,
#  'LH-Clouds-EO-Rain': 0.0002862087911357011,
#  'LH-Clouds-EO-Sun': 0.0002862087911357011,
#  'LH-Clouds-EO-Clouds': 0.0002862087911357011,
#  'LH-Clouds-EO-Snow': 0.0002862087911357011,
#  'LH-Clouds-EO-Fog': 0.0002862087911357011,
#  'LH-Clouds-SV-Rain': 0.00015233693721738932,
#  'LH-Clouds-SV-Sun': 0.00015233693721738932,
#  'LH-Clouds-SV-Clouds': 0.00015233693721738932,
#  'LH-Clouds-SV-Snow': 0.00015233693721738932,
#  'LH-Clouds-SV-Fog': 0.00015233693721738932,
#  'LH-Clouds-DK-Rain': 0.00014772066639261993,
#  'LH-Clouds-DK-Sun': 0.00014772066639261993,
#  'LH-Clouds-DK-Clouds': 0.00014772066639261993,
#  'LH-Clouds-DK-Snow': 0.00014772066639261993,
#  'LH-Clouds-DK-Fog': 0.00014772066639261993,
#  'LH-Clouds-NH-Rain': 4.616270824769373e-05,
#  'LH-Clouds-NH-Sun': 4.616270824769373e-05,
#  'LH-Clouds-NH-Clouds': 4.616270824769373e-05,
#  'LH-Clouds-NH-Snow': 4.616270824769373e-05,
#  'LH-Clouds-NH-Fog': 4.616270824769373e-05,
#  'LH-Clouds-KR-Rain': 1.8465083299077492e-05,
#  'LH-Clouds-KR-Sun': 1.8465083299077492e-05,
#  'LH-Clouds-KR-Clouds': 1.8465083299077492e-05,
#  'LH-Clouds-KR-Snow': 1.8465083299077492e-05,
#  'LH-Clouds-KR-Fog': 1.8465083299077492e-05,
#  'LH-Clouds-AG-Rain': 1.8465083299077492e-05,
#  'LH-Clouds-AG-Sun': 1.8465083299077492e-05,
#  'LH-Clouds-AG-Clouds': 1.8465083299077492e-05,
#  'LH-Clouds-AG-Snow': 1.8465083299077492e-05,
#  'LH-Clouds-AG-Fog': 1.8465083299077492e-05,
#  'LH-Clouds-GR-Rain': 1.3848812474308116e-05,
#  'LH-Clouds-GR-Sun': 1.3848812474308116e-05,
#  'LH-Clouds-GR-Clouds': 1.3848812474308116e-05,
#  'LH-Clouds-GR-Snow': 1.3848812474308116e-05,
#  'LH-Clouds-GR-Fog': 1.3848812474308116e-05,
#  'LH-Clouds-RG-Rain': 9.232541649538746e-06,
#  'LH-Clouds-RG-Sun': 9.232541649538746e-06,
#  'LH-Clouds-RG-Clouds': 9.232541649538746e-06,
#  'LH-Clouds-RG-Snow': 9.232541649538746e-06,
#  'LH-Clouds-RG-Fog': 9.232541649538746e-06,
#  'LH-Clouds-KM-Rain': 4.616270824769373e-06,
#  'LH-Clouds-KM-Sun': 4.616270824769373e-06,
#  'LH-Clouds-KM-Clouds': 4.616270824769373e-06,
#  'LH-Clouds-KM-Snow': 4.616270824769373e-06,
#  'LH-Clouds-KM-Fog': 4.616270824769373e-06,
#  'LH-Clouds-NL-Rain': 0.0,
#  'LH-Clouds-NL-Sun': 0.0,
#  'LH-Clouds-NL-Clouds': 0.0,
#  'LH-Clouds-NL-Snow': 0.0,
#  'LH-Clouds-NL-Fog': 0.0,
#  'LH-Clouds-JA-Rain': 0.0,
#  'LH-Clouds-JA-Sun': 0.0,
#  'LH-Clouds-JA-Clouds': 0.0,
#  'LH-Clouds-JA-Snow': 0.0,
#  'LH-Clouds-JA-Fog': 0.0,
#  'LH-Clouds-PF-Rain': 0.0,
#  'LH-Clouds-PF-Sun': 0.0,
#  'LH-Clouds-PF-Clouds': 0.0,
#  'LH-Clouds-PF-Snow': 0.0,
#  'LH-Clouds-PF-Fog': 0.0,
#  'LH-Snow-LH-Rain': 0.0016018459761949723,
#  'LH-Snow-LH-Sun': 0.0016018459761949723,
#  'LH-Snow-LH-Clouds': 0.0016018459761949723,
#  'LH-Snow-LH-Snow': 0.0016018459761949723,
#  'LH-Snow-LH-Fog': 0.0016018459761949723,
#  'LH-Snow-VB-Rain': 0.0010294283939235702,
#  'LH-Snow-VB-Sun': 0.0010294283939235702,
#  'LH-Snow-VB-Clouds': 0.0010294283939235702,
#  'LH-Snow-VB-Snow': 0.0010294283939235702,
#  'LH-Snow-VB-Fog': 0.0010294283939235702,
#  'LH-Snow-MV-Rain': 0.0009878819565006455,
#  'LH-Snow-MV-Sun': 0.0009878819565006455,
#  'LH-Snow-MV-Clouds': 0.0009878819565006455,
#  'LH-Snow-MV-Snow': 0.0009878819565006455,
#  'LH-Snow-MV-Fog': 0.0009878819565006455,
#  'LH-Snow-SP-Rain': 0.0005770338530961715,
#  'LH-Snow-SP-Sun': 0.0005770338530961715,
#  'LH-Snow-SP-Clouds': 0.0005770338530961715,
#  'LH-Snow-SP-Snow': 0.0005770338530961715,
#  'LH-Snow-SP-Fog': 0.0005770338530961715,
#  'LH-Snow-DR-Rain': 0.0005493362281475554,
#  'LH-Snow-DR-Sun': 0.0005493362281475554,
#  'LH-Snow-DR-Clouds': 0.0005493362281475554,
#  'LH-Snow-DR-Snow': 0.0005493362281475554,
#  'LH-Snow-DR-Fog': 0.0005493362281475554,
#  'LH-Snow-CS-Rain': 0.00048470843660078415,
#  'LH-Snow-CS-Sun': 0.00048470843660078415,
#  'LH-Snow-CS-Clouds': 0.00048470843660078415,
#  'LH-Snow-CS-Snow': 0.00048470843660078415,
#  'LH-Snow-CS-Fog': 0.00048470843660078415,
#  'LH-Snow-AA-Rain': 0.00048470843660078415,
#  'LH-Snow-AA-Sun': 0.00048470843660078415,
#  'LH-Snow-AA-Clouds': 0.00048470843660078415,
#  'LH-Snow-AA-Snow': 0.00048470843660078415,
#  'LH-Snow-AA-Fog': 0.00048470843660078415,
#  'LH-Snow-CL-Rain': 0.00045239454082739855,
#  'LH-Snow-CL-Sun': 0.00045239454082739855,
#  'LH-Snow-CL-Clouds': 0.00045239454082739855,
#  'LH-Snow-CL-Snow': 0.00045239454082739855,
#  'LH-Snow-CL-Fog': 0.00045239454082739855,
#  'LH-Snow-LN-Rain': 0.0004477782700026291,
#  'LH-Snow-LN-Sun': 0.0004477782700026291,
#  'LH-Snow-LN-Clouds': 0.0004477782700026291,
#  'LH-Snow-LN-Snow': 0.0004477782700026291,
#  'LH-Snow-LN-Fog': 0.0004477782700026291,
#  'LH-Snow-PG-Rain': 0.0003462203118577029,
#  'LH-Snow-PG-Sun': 0.0003462203118577029,
#  'LH-Snow-PG-Clouds': 0.0003462203118577029,
#  'LH-Snow-PG-Snow': 0.0003462203118577029,
#  'LH-Snow-PG-Fog': 0.0003462203118577029,
#  'LH-Snow-LS-Rain': 0.0003462203118577029,
#  'LH-Snow-LS-Sun': 0.0003462203118577029,
#  'LH-Snow-LS-Clouds': 0.0003462203118577029,
#  'LH-Snow-LS-Snow': 0.0003462203118577029,
#  'LH-Snow-LS-Fog': 0.0003462203118577029,
#  'LH-Snow-EO-Rain': 0.0002862087911357011,
#  'LH-Snow-EO-Sun': 0.0002862087911357011,
#  'LH-Snow-EO-Clouds': 0.0002862087911357011,
#  'LH-Snow-EO-Snow': 0.0002862087911357011,
#  'LH-Snow-EO-Fog': 0.0002862087911357011,
#  'LH-Snow-SV-Rain': 0.00015233693721738932,
#  'LH-Snow-SV-Sun': 0.00015233693721738932,
#  'LH-Snow-SV-Clouds': 0.00015233693721738932,
#  'LH-Snow-SV-Snow': 0.00015233693721738932,
#  'LH-Snow-SV-Fog': 0.00015233693721738932,
#  'LH-Snow-DK-Rain': 0.00014772066639261993,
#  'LH-Snow-DK-Sun': 0.00014772066639261993,
#  'LH-Snow-DK-Clouds': 0.00014772066639261993,
#  'LH-Snow-DK-Snow': 0.00014772066639261993,
#  'LH-Snow-DK-Fog': 0.00014772066639261993,
#  'LH-Snow-NH-Rain': 4.616270824769373e-05,
#  'LH-Snow-NH-Sun': 4.616270824769373e-05,
#  'LH-Snow-NH-Clouds': 4.616270824769373e-05,
#  'LH-Snow-NH-Snow': 4.616270824769373e-05,
#  'LH-Snow-NH-Fog': 4.616270824769373e-05,
#  'LH-Snow-KR-Rain': 1.8465083299077492e-05,
#  'LH-Snow-KR-Sun': 1.8465083299077492e-05,
#  'LH-Snow-KR-Clouds': 1.8465083299077492e-05,
#  'LH-Snow-KR-Snow': 1.8465083299077492e-05,
#  'LH-Snow-KR-Fog': 1.8465083299077492e-05,
#  'LH-Snow-AG-Rain': 1.8465083299077492e-05,
#  'LH-Snow-AG-Sun': 1.8465083299077492e-05,
#  'LH-Snow-AG-Clouds': 1.8465083299077492e-05,
#  'LH-Snow-AG-Snow': 1.8465083299077492e-05,
#  'LH-Snow-AG-Fog': 1.8465083299077492e-05,
#  'LH-Snow-GR-Rain': 1.3848812474308116e-05,
#  'LH-Snow-GR-Sun': 1.3848812474308116e-05,
#  'LH-Snow-GR-Clouds': 1.3848812474308116e-05,
#  'LH-Snow-GR-Snow': 1.3848812474308116e-05,
#  'LH-Snow-GR-Fog': 1.3848812474308116e-05,
#  'LH-Snow-RG-Rain': 9.232541649538746e-06,
#  'LH-Snow-RG-Sun': 9.232541649538746e-06,
#  'LH-Snow-RG-Clouds': 9.232541649538746e-06,
#  'LH-Snow-RG-Snow': 9.232541649538746e-06,
#  'LH-Snow-RG-Fog': 9.232541649538746e-06,
#  'LH-Snow-KM-Rain': 4.616270824769373e-06,
#  'LH-Snow-KM-Sun': 4.616270824769373e-06,
#  'LH-Snow-KM-Clouds': 4.616270824769373e-06,
#  'LH-Snow-KM-Snow': 4.616270824769373e-06,
#  'LH-Snow-KM-Fog': 4.616270824769373e-06,
#  'LH-Snow-NL-Rain': 0.0,
#  'LH-Snow-NL-Sun': 0.0,
#  'LH-Snow-NL-Clouds': 0.0,
#  'LH-Snow-NL-Snow': 0.0,
#  'LH-Snow-NL-Fog': 0.0,
#  'LH-Snow-JA-Rain': 0.0,
#  'LH-Snow-JA-Sun': 0.0,
#  'LH-Snow-JA-Clouds': 0.0,
#  'LH-Snow-JA-Snow': 0.0,
#  'LH-Snow-JA-Fog': 0.0,
#  'LH-Snow-PF-Rain': 0.0,
#  'LH-Snow-PF-Sun': 0.0,
#  'LH-Snow-PF-Clouds': 0.0,
#  'LH-Snow-PF-Snow': 0.0,
#  'LH-Snow-PF-Fog': 0.0,
#  'LH-Fog-LH-Rain': 0.0016018459761949723,
#  'LH-Fog-LH-Sun': 0.0016018459761949723,
#  'LH-Fog-LH-Clouds': 0.0016018459761949723,
#  'LH-Fog-LH-Snow': 0.0016018459761949723,
#  'LH-Fog-LH-Fog': 0.0016018459761949723,
#  'LH-Fog-VB-Rain': 0.0010294283939235702,
#  'LH-Fog-VB-Sun': 0.0010294283939235702,
#  'LH-Fog-VB-Clouds': 0.0010294283939235702,
#  'LH-Fog-VB-Snow': 0.0010294283939235702,
#  'LH-Fog-VB-Fog': 0.0010294283939235702,
#  'LH-Fog-MV-Rain': 0.0009878819565006455,
#  'LH-Fog-MV-Sun': 0.0009878819565006455,
#  'LH-Fog-MV-Clouds': 0.0009878819565006455,
#  'LH-Fog-MV-Snow': 0.0009878819565006455,
#  'LH-Fog-MV-Fog': 0.0009878819565006455,
#  'LH-Fog-SP-Rain': 0.0005770338530961715,
#  'LH-Fog-SP-Sun': 0.0005770338530961715,
#  'LH-Fog-SP-Clouds': 0.0005770338530961715,
#  'LH-Fog-SP-Snow': 0.0005770338530961715,
#  'LH-Fog-SP-Fog': 0.0005770338530961715,
#  'LH-Fog-DR-Rain': 0.0005493362281475554,
#  'LH-Fog-DR-Sun': 0.0005493362281475554,
#  'LH-Fog-DR-Clouds': 0.0005493362281475554,
#  'LH-Fog-DR-Snow': 0.0005493362281475554,
#  'LH-Fog-DR-Fog': 0.0005493362281475554,
#  'LH-Fog-CS-Rain': 0.00048470843660078415,
#  'LH-Fog-CS-Sun': 0.00048470843660078415,
#  'LH-Fog-CS-Clouds': 0.00048470843660078415,
#  'LH-Fog-CS-Snow': 0.00048470843660078415,
#  'LH-Fog-CS-Fog': 0.00048470843660078415,
#  'LH-Fog-AA-Rain': 0.00048470843660078415,
#  'LH-Fog-AA-Sun': 0.00048470843660078415,
#  'LH-Fog-AA-Clouds': 0.00048470843660078415,
#  'LH-Fog-AA-Snow': 0.00048470843660078415,
#  'LH-Fog-AA-Fog': 0.00048470843660078415,
#  'LH-Fog-CL-Rain': 0.00045239454082739855,
#  'LH-Fog-CL-Sun': 0.00045239454082739855,
#  'LH-Fog-CL-Clouds': 0.00045239454082739855,
#  'LH-Fog-CL-Snow': 0.00045239454082739855,
#  'LH-Fog-CL-Fog': 0.00045239454082739855,
#  'LH-Fog-LN-Rain': 0.0004477782700026291,
#  'LH-Fog-LN-Sun': 0.0004477782700026291,
#  'LH-Fog-LN-Clouds': 0.0004477782700026291,
#  'LH-Fog-LN-Snow': 0.0004477782700026291,
#  'LH-Fog-LN-Fog': 0.0004477782700026291,
#  'LH-Fog-PG-Rain': 0.0003462203118577029,
#  'LH-Fog-PG-Sun': 0.0003462203118577029,
#  'LH-Fog-PG-Clouds': 0.0003462203118577029,
#  'LH-Fog-PG-Snow': 0.0003462203118577029,
#  'LH-Fog-PG-Fog': 0.0003462203118577029,
#  'LH-Fog-LS-Rain': 0.0003462203118577029,
#  'LH-Fog-LS-Sun': 0.0003462203118577029,
#  'LH-Fog-LS-Clouds': 0.0003462203118577029,
#  'LH-Fog-LS-Snow': 0.0003462203118577029,
#  'LH-Fog-LS-Fog': 0.0003462203118577029,
#  'LH-Fog-EO-Rain': 0.0002862087911357011,
#  'LH-Fog-EO-Sun': 0.0002862087911357011,
#  'LH-Fog-EO-Clouds': 0.0002862087911357011,
#  'LH-Fog-EO-Snow': 0.0002862087911357011,
#  'LH-Fog-EO-Fog': 0.0002862087911357011,
#  'LH-Fog-SV-Rain': 0.00015233693721738932,
#  'LH-Fog-SV-Sun': 0.00015233693721738932,
#  'LH-Fog-SV-Clouds': 0.00015233693721738932,
#  'LH-Fog-SV-Snow': 0.00015233693721738932,
#  'LH-Fog-SV-Fog': 0.00015233693721738932,
#  'LH-Fog-DK-Rain': 0.00014772066639261993,
#  'LH-Fog-DK-Sun': 0.00014772066639261993,
#  'LH-Fog-DK-Clouds': 0.00014772066639261993,
#  'LH-Fog-DK-Snow': 0.00014772066639261993,
#  'LH-Fog-DK-Fog': 0.00014772066639261993,
#  'LH-Fog-NH-Rain': 4.616270824769373e-05,
#  'LH-Fog-NH-Sun': 4.616270824769373e-05,
#  'LH-Fog-NH-Clouds': 4.616270824769373e-05,
#  'LH-Fog-NH-Snow': 4.616270824769373e-05,
#  'LH-Fog-NH-Fog': 4.616270824769373e-05,
#  'LH-Fog-KR-Rain': 1.8465083299077492e-05,
#  'LH-Fog-KR-Sun': 1.8465083299077492e-05,
#  'LH-Fog-KR-Clouds': 1.8465083299077492e-05,
#  'LH-Fog-KR-Snow': 1.8465083299077492e-05,
#  'LH-Fog-KR-Fog': 1.8465083299077492e-05,
#  'LH-Fog-AG-Rain': 1.8465083299077492e-05,
#  'LH-Fog-AG-Sun': 1.8465083299077492e-05,
#  'LH-Fog-AG-Clouds': 1.8465083299077492e-05,
#  'LH-Fog-AG-Snow': 1.8465083299077492e-05,
#  'LH-Fog-AG-Fog': 1.8465083299077492e-05,
#  'LH-Fog-GR-Rain': 1.3848812474308116e-05,
#  'LH-Fog-GR-Sun': 1.3848812474308116e-05,
#  'LH-Fog-GR-Clouds': 1.3848812474308116e-05,
#  'LH-Fog-GR-Snow': 1.3848812474308116e-05,
#  'LH-Fog-GR-Fog': 1.3848812474308116e-05,
#  'LH-Fog-RG-Rain': 9.232541649538746e-06,
#  'LH-Fog-RG-Sun': 9.232541649538746e-06,
#  'LH-Fog-RG-Clouds': 9.232541649538746e-06,
#  'LH-Fog-RG-Snow': 9.232541649538746e-06,
#  'LH-Fog-RG-Fog': 9.232541649538746e-06,
#  'LH-Fog-KM-Rain': 4.616270824769373e-06,
#  'LH-Fog-KM-Sun': 4.616270824769373e-06,
#  'LH-Fog-KM-Clouds': 4.616270824769373e-06,
#  'LH-Fog-KM-Snow': 4.616270824769373e-06,
#  'LH-Fog-KM-Fog': 4.616270824769373e-06,
#  'LH-Fog-NL-Rain': 0.0,
#  'LH-Fog-NL-Sun': 0.0,
#  'LH-Fog-NL-Clouds': 0.0,
#  'LH-Fog-NL-Snow': 0.0,
#  'LH-Fog-NL-Fog': 0.0,
#  'LH-Fog-JA-Rain': 0.0,
#  'LH-Fog-JA-Sun': 0.0,
#  'LH-Fog-JA-Clouds': 0.0,
#  'LH-Fog-JA-Snow': 0.0,
#  'LH-Fog-JA-Fog': 0.0,
#  'LH-Fog-PF-Rain': 0.0,
#  'LH-Fog-PF-Sun': 0.0,
#  'LH-Fog-PF-Clouds': 0.0,
#  'LH-Fog-PF-Snow': 0.0,
#  'LH-Fog-PF-Fog': 0.0,
#  'VB-Rain-LH-Rain': 0.0010294283939235702,
#  'VB-Rain-LH-Sun': 0.0010294283939235702,
#  'VB-Rain-LH-Clouds': 0.0010294283939235702,
#  'VB-Rain-LH-Snow': 0.0010294283939235702,
#  'VB-Rain-LH-Fog': 0.0010294283939235702,
#  'VB-Rain-VB-Rain': 0.0006615634923485767,
#  'VB-Rain-VB-Sun': 0.0006615634923485767,
#  'VB-Rain-VB-Clouds': 0.0006615634923485767,
#  'VB-Rain-VB-Snow': 0.0006615634923485767,
#  'VB-Rain-VB-Fog': 0.0006615634923485767,
#  'VB-Rain-MV-Rain': 0.0006348636204600691,
#  'VB-Rain-MV-Sun': 0.0006348636204600691,
#  'VB-Rain-MV-Clouds': 0.0006348636204600691,
#  'VB-Rain-MV-Snow': 0.0006348636204600691,
#  'VB-Rain-MV-Fog': 0.0006348636204600691,
#  'VB-Rain-SP-Rain': 0.0003708315540070498,
#  'VB-Rain-SP-Sun': 0.0003708315540070498,
#  'VB-Rain-SP-Clouds': 0.0003708315540070498,
#  'VB-Rain-SP-Snow': 0.0003708315540070498,
#  'VB-Rain-SP-Fog': 0.0003708315540070498,
#  'VB-Rain-DR-Rain': 0.00035303163941471135,
#  'VB-Rain-DR-Sun': 0.00035303163941471135,
#  'VB-Rain-DR-Clouds': 0.00035303163941471135,
#  'VB-Rain-DR-Snow': 0.00035303163941471135,
#  'VB-Rain-DR-Fog': 0.00035303163941471135,
#  'VB-Rain-CS-Rain': 0.00031149850536592175,
#  'VB-Rain-CS-Sun': 0.00031149850536592175,
#  'VB-Rain-CS-Clouds': 0.00031149850536592175,
#  'VB-Rain-CS-Snow': 0.00031149850536592175,
#  'VB-Rain-CS-Fog': 0.00031149850536592175,
#  'VB-Rain-AA-Rain': 0.00031149850536592175,
#  'VB-Rain-AA-Sun': 0.00031149850536592175,
#  'VB-Rain-AA-Clouds': 0.00031149850536592175,
#  'VB-Rain-AA-Snow': 0.00031149850536592175,
#  'VB-Rain-AA-Fog': 0.00031149850536592175,
#  'VB-Rain-CL-Rain': 0.000290731938341527,
#  'VB-Rain-CL-Sun': 0.000290731938341527,
#  'VB-Rain-CL-Clouds': 0.000290731938341527,
#  'VB-Rain-CL-Snow': 0.000290731938341527,
#  'VB-Rain-CL-Fog': 0.000290731938341527,
#  'VB-Rain-LN-Rain': 0.0002877652859094706,
#  'VB-Rain-LN-Sun': 0.0002877652859094706,
#  'VB-Rain-LN-Clouds': 0.0002877652859094706,
#  'VB-Rain-LN-Snow': 0.0002877652859094706,
#  'VB-Rain-LN-Fog': 0.0002877652859094706,
#  'VB-Rain-PG-Rain': 0.00022249893240422982,
#  'VB-Rain-PG-Sun': 0.00022249893240422982,
#  'VB-Rain-PG-Clouds': 0.00022249893240422982,
#  'VB-Rain-PG-Snow': 0.00022249893240422982,
#  'VB-Rain-PG-Fog': 0.00022249893240422982,
#  'VB-Rain-LS-Rain': 0.00022249893240422982,
#  'VB-Rain-LS-Sun': 0.00022249893240422982,
#  'VB-Rain-LS-Clouds': 0.00022249893240422982,
#  'VB-Rain-LS-Snow': 0.00022249893240422982,
#  'VB-Rain-LS-Fog': 0.00022249893240422982,
#  'VB-Rain-EO-Rain': 0.0001839324507874967,
#  'VB-Rain-EO-Sun': 0.0001839324507874967,
#  'VB-Rain-EO-Clouds': 0.0001839324507874967,
#  'VB-Rain-EO-Snow': 0.0001839324507874967,
#  'VB-Rain-EO-Fog': 0.0001839324507874967,
#  'VB-Rain-SV-Rain': 9.789953025786114e-05,
#  'VB-Rain-SV-Sun': 9.789953025786114e-05,
#  'VB-Rain-SV-Clouds': 9.789953025786114e-05,
#  'VB-Rain-SV-Snow': 9.789953025786114e-05,
#  'VB-Rain-SV-Fog': 9.789953025786114e-05,
#  'VB-Rain-DK-Rain': 9.493287782580475e-05,
#  'VB-Rain-DK-Sun': 9.493287782580475e-05,
#  'VB-Rain-DK-Clouds': 9.493287782580475e-05,
#  'VB-Rain-DK-Snow': 9.493287782580475e-05,
#  'VB-Rain-DK-Fog': 9.493287782580475e-05,
#  'VB-Rain-NH-Rain': 2.9666524320563983e-05,
#  'VB-Rain-NH-Sun': 2.9666524320563983e-05,
#  'VB-Rain-NH-Clouds': 2.9666524320563983e-05,
#  'VB-Rain-NH-Snow': 2.9666524320563983e-05,
#  'VB-Rain-NH-Fog': 2.9666524320563983e-05,
#  'VB-Rain-KR-Rain': 1.1866609728225594e-05,
#  'VB-Rain-KR-Sun': 1.1866609728225594e-05,
#  'VB-Rain-KR-Clouds': 1.1866609728225594e-05,
#  'VB-Rain-KR-Snow': 1.1866609728225594e-05,
#  'VB-Rain-KR-Fog': 1.1866609728225594e-05,
#  'VB-Rain-AG-Rain': 1.1866609728225594e-05,
#  'VB-Rain-AG-Sun': 1.1866609728225594e-05,
#  'VB-Rain-AG-Clouds': 1.1866609728225594e-05,
#  'VB-Rain-AG-Snow': 1.1866609728225594e-05,
#  'VB-Rain-AG-Fog': 1.1866609728225594e-05,
#  'VB-Rain-GR-Rain': 8.899957296169194e-06,
#  'VB-Rain-GR-Sun': 8.899957296169194e-06,
#  'VB-Rain-GR-Clouds': 8.899957296169194e-06,
#  'VB-Rain-GR-Snow': 8.899957296169194e-06,
#  'VB-Rain-GR-Fog': 8.899957296169194e-06,
#  'VB-Rain-RG-Rain': 5.933304864112797e-06,
#  'VB-Rain-RG-Sun': 5.933304864112797e-06,
#  'VB-Rain-RG-Clouds': 5.933304864112797e-06,
#  'VB-Rain-RG-Snow': 5.933304864112797e-06,
#  'VB-Rain-RG-Fog': 5.933304864112797e-06,
#  'VB-Rain-KM-Rain': 2.9666524320563986e-06,
#  'VB-Rain-KM-Sun': 2.9666524320563986e-06,
#  'VB-Rain-KM-Clouds': 2.9666524320563986e-06,
#  'VB-Rain-KM-Snow': 2.9666524320563986e-06,
#  'VB-Rain-KM-Fog': 2.9666524320563986e-06,
#  'VB-Rain-NL-Rain': 0.0,
#  'VB-Rain-NL-Sun': 0.0,
#  'VB-Rain-NL-Clouds': 0.0,
#  'VB-Rain-NL-Snow': 0.0,
#  'VB-Rain-NL-Fog': 0.0,
#  'VB-Rain-JA-Rain': 0.0,
#  'VB-Rain-JA-Sun': 0.0,
#  'VB-Rain-JA-Clouds': 0.0,
#  'VB-Rain-JA-Snow': 0.0,
#  'VB-Rain-JA-Fog': 0.0,
#  'VB-Rain-PF-Rain': 0.0,
#  'VB-Rain-PF-Sun': 0.0,
#  'VB-Rain-PF-Clouds': 0.0,
#  'VB-Rain-PF-Snow': 0.0,
#  'VB-Rain-PF-Fog': 0.0,
#  'VB-Sun-LH-Rain': 0.0010294283939235702,
#  'VB-Sun-LH-Sun': 0.0010294283939235702,
#  'VB-Sun-LH-Clouds': 0.0010294283939235702,
#  'VB-Sun-LH-Snow': 0.0010294283939235702,
#  'VB-Sun-LH-Fog': 0.0010294283939235702,
#  'VB-Sun-VB-Rain': 0.0006615634923485767,
#  'VB-Sun-VB-Sun': 0.0006615634923485767,
#  'VB-Sun-VB-Clouds': 0.0006615634923485767,
#  'VB-Sun-VB-Snow': 0.0006615634923485767,
#  'VB-Sun-VB-Fog': 0.0006615634923485767,
#  'VB-Sun-MV-Rain': 0.0006348636204600691,
#  'VB-Sun-MV-Sun': 0.0006348636204600691,
#  'VB-Sun-MV-Clouds': 0.0006348636204600691,
#  'VB-Sun-MV-Snow': 0.0006348636204600691,
#  'VB-Sun-MV-Fog': 0.0006348636204600691,
#  'VB-Sun-SP-Rain': 0.0003708315540070498,
#  'VB-Sun-SP-Sun': 0.0003708315540070498,
#  'VB-Sun-SP-Clouds': 0.0003708315540070498,
#  'VB-Sun-SP-Snow': 0.0003708315540070498,
#  'VB-Sun-SP-Fog': 0.0003708315540070498,
#  'VB-Sun-DR-Rain': 0.00035303163941471135,
#  'VB-Sun-DR-Sun': 0.00035303163941471135,
#  'VB-Sun-DR-Clouds': 0.00035303163941471135,
#  'VB-Sun-DR-Snow': 0.00035303163941471135,
#  'VB-Sun-DR-Fog': 0.00035303163941471135,
#  'VB-Sun-CS-Rain': 0.00031149850536592175,
#  'VB-Sun-CS-Sun': 0.00031149850536592175,
#  'VB-Sun-CS-Clouds': 0.00031149850536592175,
#  'VB-Sun-CS-Snow': 0.00031149850536592175,
#  'VB-Sun-CS-Fog': 0.00031149850536592175,
#  'VB-Sun-AA-Rain': 0.00031149850536592175,
#  'VB-Sun-AA-Sun': 0.00031149850536592175,
#  'VB-Sun-AA-Clouds': 0.00031149850536592175,
#  'VB-Sun-AA-Snow': 0.00031149850536592175,
#  'VB-Sun-AA-Fog': 0.00031149850536592175,
#  'VB-Sun-CL-Rain': 0.000290731938341527,
#  'VB-Sun-CL-Sun': 0.000290731938341527,
#  'VB-Sun-CL-Clouds': 0.000290731938341527,
#  'VB-Sun-CL-Snow': 0.000290731938341527,
#  'VB-Sun-CL-Fog': 0.000290731938341527,
#  'VB-Sun-LN-Rain': 0.0002877652859094706,
#  'VB-Sun-LN-Sun': 0.0002877652859094706,
#  'VB-Sun-LN-Clouds': 0.0002877652859094706,
#  'VB-Sun-LN-Snow': 0.0002877652859094706,
#  'VB-Sun-LN-Fog': 0.0002877652859094706,
#  'VB-Sun-PG-Rain': 0.00022249893240422982,
#  'VB-Sun-PG-Sun': 0.00022249893240422982,
#  'VB-Sun-PG-Clouds': 0.00022249893240422982,
#  'VB-Sun-PG-Snow': 0.00022249893240422982,
#  'VB-Sun-PG-Fog': 0.00022249893240422982,
#  'VB-Sun-LS-Rain': 0.00022249893240422982,
#  'VB-Sun-LS-Sun': 0.00022249893240422982,
#  'VB-Sun-LS-Clouds': 0.00022249893240422982,
#  'VB-Sun-LS-Snow': 0.00022249893240422982,
#  'VB-Sun-LS-Fog': 0.00022249893240422982,
#  'VB-Sun-EO-Rain': 0.0001839324507874967,
#  'VB-Sun-EO-Sun': 0.0001839324507874967,
#  'VB-Sun-EO-Clouds': 0.0001839324507874967,
#  'VB-Sun-EO-Snow': 0.0001839324507874967,
#  'VB-Sun-EO-Fog': 0.0001839324507874967,
#  'VB-Sun-SV-Rain': 9.789953025786114e-05,
#  'VB-Sun-SV-Sun': 9.789953025786114e-05,
#  'VB-Sun-SV-Clouds': 9.789953025786114e-05,
#  'VB-Sun-SV-Snow': 9.789953025786114e-05,
#  'VB-Sun-SV-Fog': 9.789953025786114e-05,
#  'VB-Sun-DK-Rain': 9.493287782580475e-05,
#  'VB-Sun-DK-Sun': 9.493287782580475e-05,
#  'VB-Sun-DK-Clouds': 9.493287782580475e-05,
#  'VB-Sun-DK-Snow': 9.493287782580475e-05,
#  'VB-Sun-DK-Fog': 9.493287782580475e-05,
#  'VB-Sun-NH-Rain': 2.9666524320563983e-05,
#  'VB-Sun-NH-Sun': 2.9666524320563983e-05,
#  'VB-Sun-NH-Clouds': 2.9666524320563983e-05,
#  'VB-Sun-NH-Snow': 2.9666524320563983e-05,
#  'VB-Sun-NH-Fog': 2.9666524320563983e-05,
#  'VB-Sun-KR-Rain': 1.1866609728225594e-05,
#  'VB-Sun-KR-Sun': 1.1866609728225594e-05,
#  'VB-Sun-KR-Clouds': 1.1866609728225594e-05,
#  'VB-Sun-KR-Snow': 1.1866609728225594e-05,
#  'VB-Sun-KR-Fog': 1.1866609728225594e-05,
#  'VB-Sun-AG-Rain': 1.1866609728225594e-05,
#  'VB-Sun-AG-Sun': 1.1866609728225594e-05,
#  'VB-Sun-AG-Clouds': 1.1866609728225594e-05,
#  'VB-Sun-AG-Snow': 1.1866609728225594e-05,
#  'VB-Sun-AG-Fog': 1.1866609728225594e-05,
#  'VB-Sun-GR-Rain': 8.899957296169194e-06,
#  'VB-Sun-GR-Sun': 8.899957296169194e-06,
#  'VB-Sun-GR-Clouds': 8.899957296169194e-06,
#  'VB-Sun-GR-Snow': 8.899957296169194e-06,
#  'VB-Sun-GR-Fog': 8.899957296169194e-06,
#  'VB-Sun-RG-Rain': 5.933304864112797e-06,
#  'VB-Sun-RG-Sun': 5.933304864112797e-06,
#  'VB-Sun-RG-Clouds': 5.933304864112797e-06,
#  'VB-Sun-RG-Snow': 5.933304864112797e-06,
#  'VB-Sun-RG-Fog': 5.933304864112797e-06,
#  'VB-Sun-KM-Rain': 2.9666524320563986e-06,
#  'VB-Sun-KM-Sun': 2.9666524320563986e-06,
#  'VB-Sun-KM-Clouds': 2.9666524320563986e-06,
#  'VB-Sun-KM-Snow': 2.9666524320563986e-06,
#  'VB-Sun-KM-Fog': 2.9666524320563986e-06,
#  'VB-Sun-NL-Rain': 0.0,
#  'VB-Sun-NL-Sun': 0.0,
#  'VB-Sun-NL-Clouds': 0.0,
#  'VB-Sun-NL-Snow': 0.0,
#  'VB-Sun-NL-Fog': 0.0,
#  'VB-Sun-JA-Rain': 0.0,
#  'VB-Sun-JA-Sun': 0.0,
#  'VB-Sun-JA-Clouds': 0.0,
#  'VB-Sun-JA-Snow': 0.0,
#  'VB-Sun-JA-Fog': 0.0,
#  'VB-Sun-PF-Rain': 0.0,
#  'VB-Sun-PF-Sun': 0.0,
#  'VB-Sun-PF-Clouds': 0.0,
#  'VB-Sun-PF-Snow': 0.0,
#  'VB-Sun-PF-Fog': 0.0,
#  'VB-Clouds-LH-Rain': 0.0010294283939235702,
#  'VB-Clouds-LH-Sun': 0.0010294283939235702,
#  'VB-Clouds-LH-Clouds': 0.0010294283939235702,
#  'VB-Clouds-LH-Snow': 0.0010294283939235702,
#  'VB-Clouds-LH-Fog': 0.0010294283939235702,
#  'VB-Clouds-VB-Rain': 0.0006615634923485767,
#  'VB-Clouds-VB-Sun': 0.0006615634923485767,
#  'VB-Clouds-VB-Clouds': 0.0006615634923485767,
#  'VB-Clouds-VB-Snow': 0.0006615634923485767,
#  'VB-Clouds-VB-Fog': 0.0006615634923485767,
#  'VB-Clouds-MV-Rain': 0.0006348636204600691,
#  'VB-Clouds-MV-Sun': 0.0006348636204600691,
#  'VB-Clouds-MV-Clouds': 0.0006348636204600691,
#  'VB-Clouds-MV-Snow': 0.0006348636204600691,
#  'VB-Clouds-MV-Fog': 0.0006348636204600691,
#  'VB-Clouds-SP-Rain': 0.0003708315540070498,
#  'VB-Clouds-SP-Sun': 0.0003708315540070498,
#  'VB-Clouds-SP-Clouds': 0.0003708315540070498,
#  'VB-Clouds-SP-Snow': 0.0003708315540070498,
#  'VB-Clouds-SP-Fog': 0.0003708315540070498,
#  'VB-Clouds-DR-Rain': 0.00035303163941471135,
#  'VB-Clouds-DR-Sun': 0.00035303163941471135,
#  'VB-Clouds-DR-Clouds': 0.00035303163941471135,
#  'VB-Clouds-DR-Snow': 0.00035303163941471135,
#  'VB-Clouds-DR-Fog': 0.00035303163941471135,
#  'VB-Clouds-CS-Rain': 0.00031149850536592175,
#  'VB-Clouds-CS-Sun': 0.00031149850536592175,
#  'VB-Clouds-CS-Clouds': 0.00031149850536592175,
#  'VB-Clouds-CS-Snow': 0.00031149850536592175,
#  'VB-Clouds-CS-Fog': 0.00031149850536592175,
#  'VB-Clouds-AA-Rain': 0.00031149850536592175,
#  'VB-Clouds-AA-Sun': 0.00031149850536592175,
#  'VB-Clouds-AA-Clouds': 0.00031149850536592175,
#  'VB-Clouds-AA-Snow': 0.00031149850536592175,
#  'VB-Clouds-AA-Fog': 0.00031149850536592175,
#  'VB-Clouds-CL-Rain': 0.000290731938341527,
#  'VB-Clouds-CL-Sun': 0.000290731938341527,
#  'VB-Clouds-CL-Clouds': 0.000290731938341527,
#  'VB-Clouds-CL-Snow': 0.000290731938341527,
#  'VB-Clouds-CL-Fog': 0.000290731938341527,
#  'VB-Clouds-LN-Rain': 0.0002877652859094706,
#  'VB-Clouds-LN-Sun': 0.0002877652859094706,
#  'VB-Clouds-LN-Clouds': 0.0002877652859094706,
#  'VB-Clouds-LN-Snow': 0.0002877652859094706,
#  'VB-Clouds-LN-Fog': 0.0002877652859094706,
#  'VB-Clouds-PG-Rain': 0.00022249893240422982,
#  'VB-Clouds-PG-Sun': 0.00022249893240422982,
#  'VB-Clouds-PG-Clouds': 0.00022249893240422982,
#  'VB-Clouds-PG-Snow': 0.00022249893240422982,
#  'VB-Clouds-PG-Fog': 0.00022249893240422982,
#  'VB-Clouds-LS-Rain': 0.00022249893240422982,
#  'VB-Clouds-LS-Sun': 0.00022249893240422982,
#  'VB-Clouds-LS-Clouds': 0.00022249893240422982,
#  'VB-Clouds-LS-Snow': 0.00022249893240422982,
#  'VB-Clouds-LS-Fog': 0.00022249893240422982,
#  'VB-Clouds-EO-Rain': 0.0001839324507874967,
#  'VB-Clouds-EO-Sun': 0.0001839324507874967,
#  'VB-Clouds-EO-Clouds': 0.0001839324507874967,
#  'VB-Clouds-EO-Snow': 0.0001839324507874967,
#  'VB-Clouds-EO-Fog': 0.0001839324507874967,
#  'VB-Clouds-SV-Rain': 9.789953025786114e-05,
#  'VB-Clouds-SV-Sun': 9.789953025786114e-05,
#  'VB-Clouds-SV-Clouds': 9.789953025786114e-05,
#  'VB-Clouds-SV-Snow': 9.789953025786114e-05,
#  'VB-Clouds-SV-Fog': 9.789953025786114e-05,
#  'VB-Clouds-DK-Rain': 9.493287782580475e-05,
#  'VB-Clouds-DK-Sun': 9.493287782580475e-05,
#  'VB-Clouds-DK-Clouds': 9.493287782580475e-05,
#  'VB-Clouds-DK-Snow': 9.493287782580475e-05,
#  'VB-Clouds-DK-Fog': 9.493287782580475e-05,
#  'VB-Clouds-NH-Rain': 2.9666524320563983e-05,
#  'VB-Clouds-NH-Sun': 2.9666524320563983e-05,
#  'VB-Clouds-NH-Clouds': 2.9666524320563983e-05,
#  'VB-Clouds-NH-Snow': 2.9666524320563983e-05,
#  'VB-Clouds-NH-Fog': 2.9666524320563983e-05,
#  'VB-Clouds-KR-Rain': 1.1866609728225594e-05,
#  'VB-Clouds-KR-Sun': 1.1866609728225594e-05,
#  'VB-Clouds-KR-Clouds': 1.1866609728225594e-05,
#  'VB-Clouds-KR-Snow': 1.1866609728225594e-05,
#  'VB-Clouds-KR-Fog': 1.1866609728225594e-05,
#  'VB-Clouds-AG-Rain': 1.1866609728225594e-05,
#  'VB-Clouds-AG-Sun': 1.1866609728225594e-05,
#  'VB-Clouds-AG-Clouds': 1.1866609728225594e-05,
#  'VB-Clouds-AG-Snow': 1.1866609728225594e-05,
#  'VB-Clouds-AG-Fog': 1.1866609728225594e-05,
#  'VB-Clouds-GR-Rain': 8.899957296169194e-06,
#  'VB-Clouds-GR-Sun': 8.899957296169194e-06,
#  'VB-Clouds-GR-Clouds': 8.899957296169194e-06,
#  'VB-Clouds-GR-Snow': 8.899957296169194e-06,
#  'VB-Clouds-GR-Fog': 8.899957296169194e-06,
#  'VB-Clouds-RG-Rain': 5.933304864112797e-06,
#  'VB-Clouds-RG-Sun': 5.933304864112797e-06,
#  'VB-Clouds-RG-Clouds': 5.933304864112797e-06,
#  'VB-Clouds-RG-Snow': 5.933304864112797e-06,
#  'VB-Clouds-RG-Fog': 5.933304864112797e-06,
#  'VB-Clouds-KM-Rain': 2.9666524320563986e-06,
#  'VB-Clouds-KM-Sun': 2.9666524320563986e-06,
#  'VB-Clouds-KM-Clouds': 2.9666524320563986e-06,
#  'VB-Clouds-KM-Snow': 2.9666524320563986e-06,
#  'VB-Clouds-KM-Fog': 2.9666524320563986e-06,
#  'VB-Clouds-NL-Rain': 0.0,
#  'VB-Clouds-NL-Sun': 0.0,
#  'VB-Clouds-NL-Clouds': 0.0,
#  'VB-Clouds-NL-Snow': 0.0,
#  'VB-Clouds-NL-Fog': 0.0,
#  'VB-Clouds-JA-Rain': 0.0,
#  'VB-Clouds-JA-Sun': 0.0,
#  'VB-Clouds-JA-Clouds': 0.0,
#  'VB-Clouds-JA-Snow': 0.0,
#  'VB-Clouds-JA-Fog': 0.0,
#  'VB-Clouds-PF-Rain': 0.0,
#  'VB-Clouds-PF-Sun': 0.0,
#  'VB-Clouds-PF-Clouds': 0.0,
#  'VB-Clouds-PF-Snow': 0.0,
#  'VB-Clouds-PF-Fog': 0.0,
#  'VB-Snow-LH-Rain': 0.0010294283939235702,
#  'VB-Snow-LH-Sun': 0.0010294283939235702,
#  'VB-Snow-LH-Clouds': 0.0010294283939235702,
#  'VB-Snow-LH-Snow': 0.0010294283939235702,
#  'VB-Snow-LH-Fog': 0.0010294283939235702,
#  'VB-Snow-VB-Rain': 0.0006615634923485767,
#  'VB-Snow-VB-Sun': 0.0006615634923485767,
#  'VB-Snow-VB-Clouds': 0.0006615634923485767,
#  'VB-Snow-VB-Snow': 0.0006615634923485767,
#  'VB-Snow-VB-Fog': 0.0006615634923485767,
#  'VB-Snow-MV-Rain': 0.0006348636204600691,
#  'VB-Snow-MV-Sun': 0.0006348636204600691,
#  'VB-Snow-MV-Clouds': 0.0006348636204600691,
#  'VB-Snow-MV-Snow': 0.0006348636204600691,
#  'VB-Snow-MV-Fog': 0.0006348636204600691,
#  'VB-Snow-SP-Rain': 0.0003708315540070498,
#  'VB-Snow-SP-Sun': 0.0003708315540070498,
#  'VB-Snow-SP-Clouds': 0.0003708315540070498,
#  'VB-Snow-SP-Snow': 0.0003708315540070498,
#  'VB-Snow-SP-Fog': 0.0003708315540070498,
#  'VB-Snow-DR-Rain': 0.00035303163941471135,
#  'VB-Snow-DR-Sun': 0.00035303163941471135,
#  'VB-Snow-DR-Clouds': 0.00035303163941471135,
#  'VB-Snow-DR-Snow': 0.00035303163941471135,
#  'VB-Snow-DR-Fog': 0.00035303163941471135,
#  'VB-Snow-CS-Rain': 0.00031149850536592175,
#  'VB-Snow-CS-Sun': 0.00031149850536592175,
#  'VB-Snow-CS-Clouds': 0.00031149850536592175,
#  'VB-Snow-CS-Snow': 0.00031149850536592175,
#  'VB-Snow-CS-Fog': 0.00031149850536592175,
#  'VB-Snow-AA-Rain': 0.00031149850536592175,
#  'VB-Snow-AA-Sun': 0.00031149850536592175,
#  'VB-Snow-AA-Clouds': 0.00031149850536592175,
#  'VB-Snow-AA-Snow': 0.00031149850536592175,
#  'VB-Snow-AA-Fog': 0.00031149850536592175,
#  'VB-Snow-CL-Rain': 0.000290731938341527,
#  'VB-Snow-CL-Sun': 0.000290731938341527,
#  'VB-Snow-CL-Clouds': 0.000290731938341527,
#  'VB-Snow-CL-Snow': 0.000290731938341527,
#  'VB-Snow-CL-Fog': 0.000290731938341527,
#  'VB-Snow-LN-Rain': 0.0002877652859094706,
#  'VB-Snow-LN-Sun': 0.0002877652859094706,
#  'VB-Snow-LN-Clouds': 0.0002877652859094706,
#  'VB-Snow-LN-Snow': 0.0002877652859094706,
#  'VB-Snow-LN-Fog': 0.0002877652859094706,
#  'VB-Snow-PG-Rain': 0.00022249893240422982,
#  'VB-Snow-PG-Sun': 0.00022249893240422982,
#  'VB-Snow-PG-Clouds': 0.00022249893240422982,
#  'VB-Snow-PG-Snow': 0.00022249893240422982,
#  'VB-Snow-PG-Fog': 0.00022249893240422982,
#  'VB-Snow-LS-Rain': 0.00022249893240422982,
#  'VB-Snow-LS-Sun': 0.00022249893240422982,
#  'VB-Snow-LS-Clouds': 0.00022249893240422982,
#  'VB-Snow-LS-Snow': 0.00022249893240422982,
#  'VB-Snow-LS-Fog': 0.00022249893240422982,
#  'VB-Snow-EO-Rain': 0.0001839324507874967,
#  'VB-Snow-EO-Sun': 0.0001839324507874967,
#  'VB-Snow-EO-Clouds': 0.0001839324507874967,
#  'VB-Snow-EO-Snow': 0.0001839324507874967,
#  'VB-Snow-EO-Fog': 0.0001839324507874967,
#  'VB-Snow-SV-Rain': 9.789953025786114e-05,
#  'VB-Snow-SV-Sun': 9.789953025786114e-05,
#  'VB-Snow-SV-Clouds': 9.789953025786114e-05,
#  'VB-Snow-SV-Snow': 9.789953025786114e-05,
#  'VB-Snow-SV-Fog': 9.789953025786114e-05,
#  'VB-Snow-DK-Rain': 9.493287782580475e-05,
#  'VB-Snow-DK-Sun': 9.493287782580475e-05,
#  'VB-Snow-DK-Clouds': 9.493287782580475e-05,
#  'VB-Snow-DK-Snow': 9.493287782580475e-05,
#  'VB-Snow-DK-Fog': 9.493287782580475e-05,
#  'VB-Snow-NH-Rain': 2.9666524320563983e-05,
#  'VB-Snow-NH-Sun': 2.9666524320563983e-05,
#  'VB-Snow-NH-Clouds': 2.9666524320563983e-05,
#  'VB-Snow-NH-Snow': 2.9666524320563983e-05,
#  'VB-Snow-NH-Fog': 2.9666524320563983e-05,
#  'VB-Snow-KR-Rain': 1.1866609728225594e-05,
#  'VB-Snow-KR-Sun': 1.1866609728225594e-05,
#  'VB-Snow-KR-Clouds': 1.1866609728225594e-05,
#  'VB-Snow-KR-Snow': 1.1866609728225594e-05,
#  'VB-Snow-KR-Fog': 1.1866609728225594e-05,
#  ...}

# %% [markdown]
# #### Probability that Mercedes wins atleast one of these races on a rainy day,

# %%
def mercedes_atleast_one_rainy(outcome): return 'LH-Rain' in outcome or 'VB-Rain' in outcome

# %%
p(mercedes_atleast_one_rainy, WJ)
# Out:
# 0.12716562301696843

# %%
def mercedes_first_win(outcome):
    return outcome.split('-')[0] == 'LH' or outcome.split('-')[0] == 'VB'

def mercedes_second_win(outcome):
    return outcome.split('-')[2] == 'LH' or outcome.split('-')[2] == 'VB'

# %%
p(mercedes_second_win, such_that(mercedes_first_win, WJ))
# Out:
# 0.3287197231833912
