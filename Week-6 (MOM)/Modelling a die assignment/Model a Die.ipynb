# %% [markdown]
# ### Assignment Problem Statement:
#
# #### 1. How to model throwing a die with data science? Is that a perfectly random event, or not? What is the histogram that matches the experiment? Build a model (i.e. its histogram)
#
# #### 2. Then build a randomly weighted die (i.e. the histogram of a die that produces numbers with random probabilities)
#
# #### 3. Then build a weighted die that matches a gaussian distribution instead (in other words, a weighted die with a gaussian-looking histogram).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats

x = [1,2,3,4,5,6]
counts, bins = np.histogram(x, bins= 100)
bins = bins[:-1] + (bins[1] - bins[0])/2
probs = counts/float(counts.sum())
print(probs.sum()) # 1.0
plt.bar(bins, probs)
plt.show()
# Out:
# 0.9999999999999999

# %% [markdown]
# #### Fair die

# %%
probs = np.full((6), 1/6) #Return a new array of shape (6) and type, filled with 1/6
face = [1,2,3,4,5,6]
plt.bar(face, probs)
plt.ylabel('Probability', fontsize=12)
plt.xlabel('Die Roll Outcome', fontsize=12)
plt.title('Fair Die - Uniform Distribution', fontsize=12)
axes = plt.gca()
axes.set_ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# #### Randomly weighted die

# %%
probs = np.array([0.25, 0.125, 0.05, 0.4, 0.125, 0.05])
face = [1,2,3,4,5,6]
plt.bar(face, probs)
plt.title('Weighted die (Non Uniform Distribution)', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.xlabel('Die Roll Outcome', fontsize=12)
axes = plt.gca()
axes.set_ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# #### Gaussian distribution

# %%
n = np.arange(1, 7)
mean = 3.5
gaussian_dice = stats.norm.pdf(n, mean)
plt.plot(n, gaussian_dice)

face = [1,2,3,4,5,6]
plt.bar(face, gaussian_dice)
plt.title('Weighted die (Gausian distribution)', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.xlabel('Dice Roll Outcome', fontsize=12)
axes = plt.gca()
axes.set_ylim([0,1])
# Out:
# (0.0, 1.0)
